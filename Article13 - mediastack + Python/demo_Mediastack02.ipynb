# %% [markdown]
# # Easily Automate News Scraping with mediastack

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
# Python 3
import http.client, urllib.parse

conn = http.client.HTTPConnection('api.mediastack.com')

params = urllib.parse.urlencode({
    'access_key': 'YOUR_ACCESS_KEY',
    'categories': '-general,-sports',
    'sort': 'published_desc',
    'limit': 10,
    })

conn.request('GET', '/v1/news?{}'.format(params))

res = conn.getresponse()
data = res.read()

print(data.decode('utf-8'))
# Out:
# {"pagination":{"limit":10,"offset":0,"count":10,"total":10000},"data":[{"author":null,"title":"Volkswagen: Causa Diess, neue Vorst\u00e4nde, Milliardeninvestitionen: Was die VW-Aufseher heute beschlie\u00dfen wollen","description":"\u00dcber die Zukunft des VW-Chefs Diess ist zuletzt intensiv diskutiert worden. Heute entscheidet der Aufsichtsrat auch \u00fcber den Investitionsplan. Die wichtigsten Fragen und Antworten.","url":"https:\/\/www.handelsblatt.com\/unternehmen\/industrie\/volkswagen-causa-diess-neue-vorstaende-milliardeninvestitionen-was-die-vw-aufseher-heute-beschliessen-wollen\/27874998.html","source":"handelsblatt","image":"https:\/\/www.handelsblatt.com\/images\/herbert-diess-bleibt-wohl-vw-chef\/27875096\/4-format2020.jpg","category":"general","language":"de","country":"de","published_at":"2021-12-09T03:13:56+00:00"},{"author":"Deporte","title":"Christiane Endler y Luis Jim\u00e9nez fueron escogidos como los mejores futbolistas del a\u00f1o por el C\u00edrculo de Periodistas Deportivos","description":"El C\u00edrculo de Periodistas Deportivos\u00a0entreg\u00f3 la n\u00f3mina de los mejores deportistas chilenos del a\u00f1o 2021\u00a0en sus distintas categor\u00edas. En total fueron\u00a060 los atletas nacionales reconocidos, entre los que destacan\u00a0Luis Jim\u00e9nez y Christiane Endler\u00a0en el mundo del f\u00fatbol, adem\u00e1s de Fernanda Vald\u00e9s, Aleza Guarachi, Paulina Vega, Yasmani Acosta, Pablo Quintanilla,\u00a0entre otros. \u201cEl C\u00edrculo de Periodistas Deportivos [\u0026#8230;]","url":"https:\/\/eldiariodesantiago.cl\/archivo\/193035","source":"radiosantiago","image":null,"category":"general","language":"es","country":"cl","published_at":"2021-12-09T03:13:56+00:00"},{"author":"Evangelina Njirjak","title":"F\u00fanebres del Jueves 9 de Diciembre de 2021","description":"La entrada F\u00fanebres del Jueves 9 de Diciembre de 2021 se public\u00f3 primero en Primera Edici\u00f3n.","url":"https:\/\/www.primeraedicion.com.ar\/nota\/100531139\/funebres-del-jueves-9-de-diciembre-de-2021\/","source":"primeraedicionweb","image":null,"category":"general","language":"es","country":"ar","published_at":"2021-12-09T03:13:31+00:00"},{"author":"Lenny Ann Low","title":"Profound life lessons from a bundle of sticks","description":"Much-loved picture-book character, Grug, is taking to the stage.","url":"https:\/\/www.watoday.com.au\/culture\/theatre\/profound-life-lessons-from-a-bundle-of-sticks-20211209-p59g83.html?ref=rss\u0026utm_medium=rss\u0026utm_source=rss_culture","source":"watoday","image":null,"category":"general","language":"en","country":"au","published_at":"2021-12-09T03:13:18+00:00"},{"author":"Lenny Ann Low","title":"Profound life lessons from a bundle of sticks","description":"Much-loved picture-book character, Grug, is taking to the stage.","url":"https:\/\/www.theage.com.au\/culture\/theatre\/profound-life-lessons-from-a-bundle-of-sticks-20211209-p59g83.html?ref=rss\u0026utm_medium=rss\u0026utm_source=rss_culture","source":"The Age","image":null,"category":"entertainment","language":"en","country":"au","published_at":"2021-12-09T03:13:18+00:00"},{"author":"Lenny Ann Low","title":"Profound life lessons from a bundle of sticks","description":"Much-loved picture-book character, Grug, is taking to the stage.","url":"https:\/\/www.smh.com.au\/culture\/theatre\/profound-life-lessons-from-a-bundle-of-sticks-20211209-p59g83.html?ref=rss\u0026utm_medium=rss\u0026utm_source=rss_feed","source":"The Sydney Morning Herald","image":null,"category":"general","language":"en","country":"au","published_at":"2021-12-09T03:13:18+00:00"},{"author":"Lenny Ann Low","title":"Profound life lessons from a bundle of sticks","description":"Much-loved picture-book character, Grug, is taking to the stage.","url":"https:\/\/www.brisbanetimes.com.au\/culture\/theatre\/profound-life-lessons-from-a-bundle-of-sticks-20211209-p59g83.html?ref=rss\u0026utm_medium=rss\u0026utm_source=rss_culture","source":"brisbanetimes","image": ...

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
# Python 3
import http.client, urllib.parse

conn = http.client.HTTPConnection('api.mediastack.com')

params = urllib.parse.urlencode({
    'access_key': 'YOUR_ACCESS_KEY',
    'categories': '-general,-sports',
    'sort': 'published_desc',
    'limit': 100,
    })

conn.request('GET', '/v1/news?{}'.format(params))

res = conn.getresponse()
data = res.read()

print(data.decode('utf-8'))
# Out:
# {"pagination":{"limit":100,"offset":0,"count":100,"total":10000},"data":[{"author":"Rishabh Bhatnagar","title":"All You Need To Know Going Into Trade On December 9","description":"All You Need To Know Going Into Trade On December 9","url":"https:\/\/www.bloombergquint.com\/markets\/all-you-need-to-know-going-into-trade-on-december-9-2","source":"Bloomberg | Latest And Live Business","image":null,"category":"business","language":"en","country":"us","published_at":"2021-12-09T01:38:31+00:00"},{"author":"Marcus Wong","title":"Indonesia\u2019s Brisk Curve Steepening Signals Fed Tightening Risk","description":"Indonesia\u2019s Brisk Curve Steepening Signals Fed Tightening Risk","url":"https:\/\/www.bloombergquint.com\/markets\/indonesia-s-brisk-curve-steepening-signals-fed-tightening-risk","source":"Bloomberg | Latest And Live Business","image":null,"category":"business","language":"en","country":"us","published_at":"2021-12-09T01:37:18+00:00"},{"author":"Daniel Flatley","title":"U.S. House Passes Bill to Punish China Over Oppression of Uyghurs","description":"U.S. House Passes Bill to Punish China Over Oppression of Uyghurs","url":"https:\/\/www.bloombergquint.com\/politics\/house-passes-bill-to-punish-china-over-oppression-of-uyghurs","source":"Bloomberg | Latest And Live Business","image":null,"category":"business","language":"en","country":"us","published_at":"2021-12-09T01:37:09+00:00"},{"author":"Jennifer Surane","title":"Citigroup Trading Revenue to Decline From Pandemic-Charged Highs","description":"Citigroup Trading Revenue to Decline From Pandemic-Charged Highs","url":"https:\/\/www.bloombergquint.com\/business\/citigroup-trading-revenue-to-decline-from-pandemic-charged-highs","source":"Bloomberg | Latest And Live Business","image":null,"category":"business","language":"en","country":"us","published_at":"2021-12-09T01:36:31+00:00"},{"author":"Lu Wang","title":"Wall Street Strategist Forecasts for 2022 Differ by Second-Most in a Decade","description":"Wall Street Strategist Forecasts for 2022 Differ by Second-Most in a Decade","url":"https:\/\/www.bloombergquint.com\/markets\/strategist-forecasts-for-2022-diverge-by-second-most-in-10-years","source":"Bloomberg | Latest And Live Business","image":null,"category":"business","language":"en","country":"us","published_at":"2021-12-09T01:33:46+00:00"},{"author":"Reuters","title":"Dollar stays soft, with Omicron still top of mind","description":"HONG KONG \u0026#8212; The dollar failed to pick up ground on most major peers on Thursday as markets saw optimism in early data hinting the Omicron variant of the new coronavirus may not be as bad as feared, even as new COVID-19 restrictions in Britain hurt the sterling. The euro was at $1.1338, after gaining [\u0026#8230;]","url":"https:\/\/financialpost.com\/pmn\/business-pmn\/dollar-stays-soft-with-omicron-still-top-of-mind","source":"Financial Post | Canada Business News","image":null,"category":"business","language":"en","country":"us","published_at":"2021-12-09T01:32:47+00:00"},{"author":"Ben Sharples","title":"Oil Extends Omicron Relief Rally With Demand Concerns Easing","description":"Oil Extends Omicron Relief Rally With Demand Concerns Easing","url":"https:\/\/www.bloombergquint.com\/markets\/oil-extends-omicron-relief-rally-with-demand-concerns-easing","source":"Bloomberg | Latest And Live Business","image":null,"category":"business","language":"en","country":"us","published_at":"2021-12-09T01:30:39+00:00"},{"author":"Andreea Papuc","title":"Asian Stocks Steady; Treasury Yields Hold Advance: Markets Wrap","description":"Asian Stocks Steady; Treasury Yields Hold Advance: Markets Wrap","url":"https:\/\/www.bloombergquint.com\/markets\/asia-stocks-to-open-steady-treasury-yields-climb-markets-wrap","source":"Bloomberg | Latest And Live Business","image":null,"category":"business","language":"en","country":"us","published_at":"2021-12-09T01:27:05+00:00"},{"author":"Chris Akor","title":"In defence of the critic","description":"Somet ...
