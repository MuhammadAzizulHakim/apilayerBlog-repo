# %% [markdown]
# # Easily Perform Advanced News Scraping with mediastack

# %% [markdown]
# ## Get Started with Python's Requests Lib

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
# Python 3
import requests

# Send GET request to mediastack API
r = requests.get("http://api.mediastack.com/v1/news?access_key=YOUR_ACCESS_KEY")

responses = r.json()
responses
# Out:
# {'pagination': {'limit': 25, 'offset': 0, 'count': 25, 'total': 10000},
#  'data': [{'author': 'Hala Abdallah',
#    'title': 'Taliban says its purge of officials unrelated to sanctioned ministers\xa0',
#    'description': 'The Taliban appointed ministers sanctioned by the US in its interim government. The Taliban has refused calls by the international community to remove ministers from its interim government under US and UN sanction threats, a senior official said according to a Sputnik report. In comments made to the Russian outlet, Taliban Spokesman Mohammad Naeem confirmed [&#8230;](The post Taliban says its purge of officials unrelated to sanctioned ministers\xa0 is from Doha News | Qatar.)',
#    'url': 'http://feedproxy.google.com/~r/DohaNews/~3/_3OlD8mmIAA/',
#    'source': 'Doha News',
#    'image': None,
#    'category': 'general',
#    'language': 'ar',
#    'country': 'qa',
#    'published_at': '2021-10-13T13:15:39+00:00'},
#   {'author': None,
#    'title': 'Le Polisario menace de «poursuivre la guerre» si «l’ONU continue de gérer la crise au lieu de la solutionner»',
#    'description': 'Alors que le conseil de sécurité examine, en ce mois d’octobre, la prolongation du mandat de la MINURSO au Sahara, le Front Polisario choisit de hausser le ton contre l’ONU. Mardi, son secrétaire général a affirmé que «la guerre est déclenchée sur le terrain et il n’est plus possible d’éviter ses risques et retombées sur la région, au cas où l’ONU continue de gérer la crise au lieu de la solutionner».',
#    'url': 'https://www.yabiladi.com/articles/details/117423/polisario-menace-poursuivre-guerre-l-onu.html',
#    'source': 'yabiladi.com',
#    'image': 'https://static.yabiladi.com/files/articles/bae736dfc95dbac510fe11ea0d82162d20211013150259150.jpg',
#    'category': 'general',
#    'language': 'ar',
#    'country': 'ma',
#    'published_at': '2021-10-13T13:20:00+00:00'},
#   {'author': 'إعلام',
#    'title': 'بعد تعافيه من كورونا.. محمد مصطفى شردي يشكر هؤلاء - E3lam.Com',
#    'description': 'وجّه الإعلامي محمد مصطفى شردي الشكر لزملائه داخل فريق عمل قناة الحياة، بعد تعافيه من الإصابة بفيروس كورونا مؤخرا',
#    'url': 'http://thinakhbarak.local/articles/42844774-%D8%A8%D8%B9%D8%AF-%D8%AA%D8%B9%D8%A7%D9%81%D9%8A%D9%87-%D9%85%D9%86-%D9%83%D9%88%D8%B1%D9%88%D9%86%D8%A7-%D9%85%D8%AD%D9%85%D8%AF-%D9%85%D8%B5%D8%B7%D9%81%D9%89-%D8%B4%D8%B1%D8%AF%D9%8A-%D9%8A%D8%B4%D9%83%D8%B1',
#    'source': 'Akhbarak.net',
#    'image': 'https://akhbarak.net/photos/articles-photos/2021/10/13/42844774/42844774-large.jpg?1634128595',
#    'category': 'general',
#    'language': 'ar',
#    'country': 'eg',
#    'published_at': '2021-10-13T12:36:30+00:00'},
#   {'author': 'Menatalla Ibrahim',
#    'title': 'Katara extends deadline for ‘Language in Holy Quran’ research competition',
#    'description': 'The first place winner will have the chance to win $30,000.\xa0 The Cultural Village Foundation (Katara) has extended the deadline for its ‘Language in the Holy Quran’ competition, the institution announced. The date has been extended for one month to 13 November at the request of participants who petitioned the competition committee, Katara added. The [&#8230;](The post Katara extends deadline for &#8216;Language in Holy Quran&#8217; research competition is from Doha News | Qatar.)',
#    'url': 'http://feedproxy.google.com/~r/DohaNews/~3/UPXu3uScMHI/',
#    'source': 'Doha News',
#    'image': None,
#    'category': 'general',
#    'language': 'ar',
#    'country': 'qa',
#    'published_at': '2021-10-12T13:45:11+00:00'},
#   {'author': None,
#    'title': "Fès : Sept arrestations dans une affaire de pratique d'avortement",
#    'description': 'La brigade régionale de la police judiciaire de Fès a ouvert, mardi, une enquête judiciaire sous la supervision du parquet compétent pour déterminer les actes criminels reprochés à sept individus, pour leur implication présumée de pratique régulière davortement, de falsification, de détournement dun mineur, dattentat à la pudeur, et de participation à la perpétration de ces actes criminels.',
#    'url': 'https://www.yabiladi.com/articles/details/117367/sept-arrestations-dans-affaire-pratique.html',
#    'source': 'yabiladi.com',
#    'image': 'https://static.yabiladi.com/files/articles/2d3ab45674f2456b84b28403db47704420211013120421150.jpg',
#    'category': 'general',
#    'language': 'ar',
#    'country': 'ma',
#    'published_at': '2021-10-13T10:20:00+00:00'},
#   {'author': None,
#    'title': 'بعد تلبية طلبه والترحيب به في &quot;ملاعب المملكة&quot;.. المدير التقني لمنتخب غينيا بيساو يصرح: &quot;التأهل صعب للغاية لأن المغرب سيلعب 5 مباريات من أصل 6 على أرضه&quot;',
#    'description': 'يرى المدير التقني لمنتخب غينيا بيساو، غويليرم فارينيا، أن منافسة بلاده للمغرب في المجموعة التاسعة لـ"تصفيات المونديال" لم تكن ممكنة، متحدثًا عن الفوارق الكبيرة بين المنتخبين والظروف التي أقيمت فيها مر',
#    'url': 'http://www.elbotola.com/article/2021-10-12-11-47-285.html',
#    'source': 'Elbotola.com',
#    'image': None,
#    'category': 'general',
#    'language': 'ar',
#    'country': 'ma',
#    'published_at': '2021-10-12T12:35:31+00:00'},
#   {'author': None,
#    'title': 'Affaire Ghali : Les députés rejettent la création d’une commission d’enquête parlementaire',
#    'description': 'La majorité gouvernementale en Espagne a rejeté la création d’une commission d’enquête parlementaire sur les circonstances de l’entrée de Brahim Ghali. Le bureau de la Chambre des représentants a voté contre une proposition du Parti Populaire.\xa0Une initiative qui n’a eu l’adhésion que du groupe de Vox.',
#    'url': 'https://www.yabiladi.com/articles/details/117469/affaire-ghali-deputes-rejettent-creation.html',
#    'source': 'yabiladi.com',
#    'image': 'https://static.yabiladi.com/files/articles/f4c621f12360501121e9462bab4222a020211013181528150.jpg',
#    'category': 'general',
#    'language': 'ar',
#    'country': 'ma',
#    'published_at': '2021-10-13T17:00:00+00:00'},
#   {'author': None,
#    'title': 'Le Royaume-Uni attend la première cargaison de fret depuis le Maroc par la route «Brexit buster»',
#    'description': 'La première cargaison de fret maritime entre le Maroc et le Royaume-Uni utilisant la nouvelle route «Brexit buster» est sur le point d’être réalisée avec l’arrivée à Poole en Angleterre de fruits et légumes biologiques de saison en provenance de Tanger.',
#    'url': 'https://www.yabiladi.com/articles/details/117380/royaume-uni-attend-premiere-cargaison-fret.html',
#    'source': 'yabiladi.com',
#    'image': 'https://static.yabiladi.com/files/articles/235bc43a6ab6c6993c33315587c74f4120211013131929150.jpg',
#    'category': 'general',
#    'language': 'ar',
#    'country': 'ma',
#    'published_at': '2021-10-13T11:37:00+00:00'},
#   {'author': None,
#    'title': 'نيمار عن &#x27;أسوأ لحظة في مسيرته&#x27;: &quot;كنت قريبا من عدم القدرة على المشي من جديد&quot;!',
#    'description': 'عاش النجم البرازيلي نيمار جونيور، "أسوأ اللحظات في مسيرته"، خلال مشاركته في كأس العالم 2014 الذي احتضنته بلاده، حينها تعرض لإصابة خطيرة على مستوى الظهر، كادت أن تنهي مشواره الكروي مبكرا.وخلال "فيلم وث',
#    'url': 'http://www.elbotola.com/article/2021-10-13-16-19-457.html',
#    'source': 'Elbotola.com',
#    'image': None,
#    'category': 'general',
#    'language': 'ar',
#    'country': 'ma',
#    'published_at': '2021-10-13T16:25:32+00:00'},
#   {'author': None,
#    'title': 'بعد السنغال.. المنتخب المغربي ثاني المتأهلين لـ&quot;الدور الفاصل&quot; من تصفيات مونديال &quot;قطر 2022&quot;',
#    'description': 'أضحى المنتخب المغربي لكرة القدم، ثاني المتأهلين للدور الفاصل من التصفيات الأفريقية لمونديال "قطر 2022"، عقب انتصاره على غينيا بأربعة أهداف مقابل واحد، في المواجهة التي جرت على البساط الأخضر لـ"المركب',
#    'url': 'http://www.elbotola.com/article/2021-10-12-22-33-286.html',
#    'source': 'Elbotola.com',
#    'image': None,
#    'category': 'general',
#    'language': 'ar',
#    'country': 'ma',
#    'published_at': '2021-10-12T22:40:31+00:00'},
#   {'author': 'Menatalla Ibrahim',
#    'title': 'This Qatari startup is going to the Hult Prize finals for a $1mn prize',
#    'description': 'The global competition offers a $1,000,000 prize.\xa0 For the first time in history, a Qatari startup has qualified for the world&#8217;s largest startup programme, the Hult Prize competition, marking a significant milestone for entrepreneurs in the Gulf state. Held annually, the Hult Prize is a year-long competition that aims to transform how youth envision their [&#8230;](The post This Qatari startup is going to the Hult Prize finals for a $1mn prize is from Doha News | Qatar.)',
#    'url': 'http://feedproxy.google.com/~r/DohaNews/~3/IWI_vs5-Qyg/',
#    'source': 'Doha News',
#    'image': None,
#    'category': 'general',
#    'language': 'ar',
#    'country': 'qa',
#    'published_at': '2021-10-27T09:28:07+00:00'},
#   {'author': None,
#    'title': 'Sahara : L’Irlande dément une «réduction» de son engagement auprès de l’ONU',
#    'description': 'Le ministère irlandais de la Défense a démenti, dimanche, une «réduction» de l’engagement de l’Irlande auprès de l’ONU, après le retrait de casques bleus irlandais mobilisés jusqu’ici dans la mission des Nations Unies du Sahara occidental (MINURSO). Selon Irish Examiner, les membres militaires irlandais faisaient partie du contingent de la mission jusquen juillet dernier.',
#    'url': 'https://www.yabiladi.com/articles/details/119414/sahara-l-irlande-dement-reduction-engagement.html',
#    'source': 'yabiladi.com',
#    'image': 'https://static.yabiladi.com/files/articles/5df5f1249de06f489446bb339f19f2f920211026183008150.jpg',
#    'category': 'general',
#    'language': 'ar',
#    'country': 'ma',
#    'published_at': '2021-10-26T17:08:00+00:00'},
#   {'author': None,
#    'title': '&quot;الكورفا سود&quot;: &quot;الرئيس الجديد مسؤول عن إعادة الثقة بين المسيرين والجماهير وبناء نموذج النادي القائم بذاته&quot;',
#    'description': 'أكدت "الكورفا سود"، المساندة للرجاء الرياضي، أن المنخرطين لهم كامل الصلاحية في التصويت على المرشح "الأصلح" في نظرهم لرئاسة الفريق خلال الفترة المقبلة، مؤكدة أن الجماهير من حقها تحميلهم مسؤولية اختياره',
#    'url': 'http://www.elbotola.com/article/2021-10-27-13-07-471.html',
#    'source': 'Elbotola.com',
#    'image': None,
#    'category': 'general',
#    'language': 'ar',
#    'country': 'ma',
#    'published_at': '2021-10-27T13:20:31+00:00'},
#   {'author': None,
#    'title': '&quot;الكاف&quot; ينفي تأجيل أو إلغاء كأس أمم أفريقيا &quot;الكاميرون 2021&quot; ويؤكد مناقشته إمكانية &quot;الحضور الجماهيري&quot;',
#    'description': 'نفى الاتحاد الأفريقي لكرة القدم، كل الأنباء التي تروج بخصوص نيته تأجيل أو إلغاء مسابقة كأس أمم أفريقيا لكرة القدم، والمزمع تنظيمها من التاسع يناير وحتى السادس من فبراير المقبلين.وكانت اللجنة التنفيذية',
#    'url': 'http://www.elbotola.com/article/2021-10-26-17-35-116.html',
#    'source': 'Elbotola.com',
#    'image': None,
#    'category': 'general',
#    'language': 'ar',
#    'country': 'ma',
#    'published_at': '2021-10-26T17:40:33+00:00'},
#   {'author': None,
#    'title': 'إعلامي فرنسي يَشُنّ هجوماً &quot;شنيعاً&quot; على حكيمي: &quot;أشرف اعتاد الحياة الباريسية.. سيغرق إذا لم يتمالك نفسه&quot;',
#    'description': 'هاجم الإعلامي الفرنسي، دانييل ريولو، بحدة، المغربي أشرف حكيمي، بعد التعادل الذي اكتفى به باريس سان جيرمان أمام أولمبيك مارسيليا، أول أمس الأحد، لحساب الجولة الـ11 من دوري الدرجة الأولى الفرنسي، مُعتبر',
#    'url': 'http://www.elbotola.com/article/2021-10-26-21-55-267.html',
#    'source': 'Elbotola.com',
#    'image': None,
#    'category': 'general',
#    'language': 'ar',
#    'country': 'ma',
#    'published_at': '2021-10-26T22:00:33+00:00'},
#   {'author': None,
#    'title': 'بعد خسارة &quot;الكلاسيكو&quot;.. برشلونة ينهزم ضد رايو فايكانو بهدف &quot;النَّمر&quot; فالكاو',
#    'description': 'تعرض إف سي برشلونة مساء يومه الأربعاء، لهزيمة جديدة في الدوري الإسباني، وسقط بهدف نظيف أمام مضيفه رايو فايكانو (1-0)، برسم الجولة الحادية عشر.ودخل المدرب رونالد كومان هذه المواجهة، بتشكيلة يقودها الأر',
#    'url': 'http://www.elbotola.com/article/2021-10-27-18-39-3.html',
#    'source': 'Elbotola.com',
#    'image': None,
#    'category': 'general',
#    'language': 'ar',
#    'country': 'ma',
#    'published_at': '2021-10-27T18:55:34+00:00'},
#   {'author': None,
#    'title': 'بايرن ميونيخ &quot;يُهان&quot; ضد بوروسيا مونشنغلادباخ بهزيمة &quot;ثقيلة&quot; (5-0) ويودع كأس ألمانيا',
#    'description': 'حقق بوروسيا مونشنغلادباخ مساء يومه الأربعاء، "مفاجأة" من العيار الثقيل، بعد أن تغلب على "العملاق" بايرن ميونيخ، بخماسية نظيفة (5-0)، في مباراة برسم الدور الثاني من كأس ألمانيا.ودخل "البافاري" هذه المب',
#    'url': 'http://www.elbotola.com/article/2021-10-27-20-37-271.html',
#    'source': 'Elbotola.com',
#    'image': None,
#    'category': 'general',
#    'language': 'ar',
#    'country': 'ma',
#    'published_at': '2021-10-27T20:40:35+00:00'},
#   {'author': None,
#    'title': 'Les circonvolutions de l’Algérie pour livrer du gaz à l’Espagne en évitant le Maroc',
#    'description': 'Alors que la ministre espagnole de la Transition écologique est à Alger, les autorités algérienne avance une nouvelle piste pour répondre aux besoins en gaz de l’Espagne.',
#    'url': 'https://www.yabiladi.com/articles/details/119604/circonvolutions-l-algerie-pour-livrer-l-espagne.html',
#    'source': 'yabiladi.com',
#    'image': 'https://static.yabiladi.com/files/articles/1a7f384c38c095c8aee3d605b7e3dae120211027183120150.png',
#    'category': 'general',
#    'language': 'ar',
#    'country': 'ma',
#    'published_at': '2021-10-27T17:00:00+00:00'},
#   {'author': None,
#    'title': "Tanger : Un ouvrier blessé dans l'effondrement partiel d'un chantier",
#    'description': 'Un ouvrier a été légèrement blessé mardi dans leffondrement partiel dun chantier de construction au niveau de lavenue Youssef Ben Tachefine à Tanger, apprend-on auprès de la wilaya de la région Tanger-Tétouan-Al Hoceima.',
#    'url': 'https://www.yabiladi.com/articles/details/119453/tanger-ouvrier-blesse-dans-l-effondrement.html',
#    'source': 'yabiladi.com',
#    'image': 'https://static.yabiladi.com/files/articles/3bfe5091b7722dbd65dde36869b336b620211027101732150.jpg',
#    'category': 'general',
#    'language': 'ar',
#    'country': 'ma',
#    'published_at': '2021-10-27T08:19:00+00:00'},
#   {'author': 'monjed jado',
#    'title': 'Palestinian Rights Committee’s Bureau Expresses Deep Concern at Israel’s Designation of Civil Society Bodies as “Terrorist Organizations”',
#    'description': 'Bethlehem/PNN/ The Bureau of the Committee on the Exercise of the Inalienable Rights of the Palestinian People expresses its deep concern at Israel&#8217;s decision of 22 October to designate six human rights and humanitarian Palestinian civil society organizations, ie, Addameer Prisoner Support and Human Rights Association; Al Haq; Defense for Children International &#8211; Palestine; Union &#8230;التدوينة Palestinian Rights Committee’s Bureau Expresses Deep Concern at Israel’s Designation of Civil Society Bodies as &#8220;Terrorist Organizations&#8221...',
#    'url': 'http://english.pnn.ps/2021/11/05/palestinian-rights-committees-bureau-expresses-deep-concern-at-israels-designation-of-civil-society-bodies-as-terrorist-organizations-2/',
#    'source': 'english',
#    'image': None,
#    'category': 'general',
#    'language': 'ar',
#    'country': 'ps',
#    'published_at': '2021-11-05T11:38:36+00:00'},
#   {'author': 'إعلام',
#    'title': 'هذا الأسبوع.. نجلاء بدر تنافس خالد الصاوي في "هزر فزر مع لولي" - E3lam.Com',
#    'description': 'يحل عدد من نجوم الفن ضيوفا على برنامج "هزر فزر مع لولي" الذي تقدمه الفنانة ليلى زاهر، يومي السبت والأحد، 6 و7 نوفمبر الجاري، على قناة cbc',
#    'url': 'http://thinakhbarak.local/articles/42978784-%D9%87%D8%B0%D8%A7-%D8%A7%D9%84%D8%A3%D8%B3%D8%A8%D9%88%D8%B9-%D9%86%D8%AC%D9%84%D8%A7%D8%A1-%D8%A8%D8%AF%D8%B1-%D8%AA%D9%86%D8%A7%D9%81%D8%B3-%D8%AE%D8%A7%D9%84%D8%AF-%D8%A7%D9%84%D8%B5%D8%A7%D9%88%D9%8A',
#    'source': 'Akhbarak.net',
#    'image': 'https://akhbarak.net/photos/articles-photos/2021/11/4/42978784/42978784-large.jpg?1636041091',
#    'category': 'general',
#    'language': 'ar',
#    'country': 'eg',
#    'published_at': '2021-11-04T15:51:25+00:00'},
#   {'author': None,
#    'title': "Maroc-Algérie : L'Espagne dit suivre «avec inquiétude» les derniers événements au Maghreb",
#    'description': 'Le ministre espagnol des Affaires étrangères, de lUE et de la coopération a reconnu, ce mercredi, que le gouvernement de son pays suit «avec inquiétude» les derniers événements au Maghreb, après que lAlgérie a accusé le Maroc davoir tué trois\xa0camionneurs algériens. Dans une déclaration au Congrès des députés, reprise par Europa Press, José Manuel Albares a assuré quil travaillera à éviter «une escalade» entre les deux pays, qu’il a qualifiés de «partenaires stratégiques» de lEspagne.',
#    'url': 'https://www.yabiladi.com/articles/details/120684/maroc-algerie-l-espagne-suivre-avec-inquietude.html',
#    'source': 'yabiladi.com',
#    'image': 'https://static.yabiladi.com/files/articles/e53a2c231f98813f662ca49bb3e4c4e520211104151747150.jpg',
#    'category': 'general',
#    'language': 'ar',
#    'country': 'ma',
#    'published_at': '2021-11-04T14:27:00+00:00'},
#   {'author': 'monjed jado',
#    'title': 'JPS & IFJ says considering an ICC case over Israel’s systematic targeting of Palestinian journalists',
#    'description': 'Ramallah/PNN/Monjed Jadou The International Federation of Journalists (IFJ) and Palestinian Journalists Syndicate (JPS) In cooperation with Palestinian and international rights groups are preparing to lodge an International Criminal Court (ICC) complaint against Israel over its “systematic targeting” of Palestinian journalists in Gaza, IFJ has said in a press release. Journalists&#8217; representative in the Palestinian Journalists &#8230;التدوينة JPS & IFJ says considering an ICC case over Israel&#8217;s systematic targeting of Palestinian journalists ظهرت أولاً على PNN...',
#    'url': 'http://english.pnn.ps/2021/11/05/jps-ifj-says-considering-an-icc-case-over-israels-systematic-targeting-of-palestinian-journalists/',
#    'source': 'english',
#    'image': None,
#    'category': 'general',
#    'language': 'ar',
#    'country': 'ps',
#    'published_at': '2021-11-05T12:04:24+00:00'},
#   {'author': 'ICT Business',
#    'title': 'Cairo ICT….محطات ونجاحات على مدار 25 عام - ICT Business Magazine - أي سي تي بيزنس',
#    'description': 'يحتفل هذا العام معرض القاهرة الدولي للتكنولوجياCairo ICT \xa0باليوبيل الفضى وسط تأكيد من عدد من الشركات',
#    'url': 'http://thinakhbarak.local/articles/42982988-Cairo-ICT-%D9%85%D8%AD%D8%B7%D8%A7%D8%AA-%D9%88%D9%86%D8%AC%D8%A7%D8%AD%D8%A7%D8%AA-%D8%B9%D9%84%D9%89-%D9%85%D8%AF%D8%A7%D8%B1-25-%D8%B9%D8%A7%D9%85--',
#    'source': 'Akhbarak.net',
#    'image': 'https://akhbarak.net/photos/articles-photos/2021/11/5/42982988/42982988-large.jpg?1636111270',
#    'category': 'general',
#    'language': 'ar',
#    'country': 'eg',
#    'published_at': '2021-11-05T11:21:06+00:00'},
#   {'author': None,
#    'title': 'Affaires des camionneurs algériens : Des éléments de la MINURSO sur le lieu de l’incident',
#    'description': 'Une équipe de la MINURSO se sont rendus, ce jeudi, sur le lieu où les trois camionneurs algériens ont trouvé la mort dans des conditions non-encore élucidées.\xa0L’envoi d’éléments de la mission onusienne atteste que l’incident s’est produit à l’Est du mur de sécurité, érigé par les Forces armées royales et non sur le territoire mauritanien.',
#    'url': 'https://www.yabiladi.com/articles/details/120677/affaires-camionneurs-algeriens-elements-minurso.html',
#    'source': 'yabiladi.com',
#    'image': 'https://static.yabiladi.com/files/articles/8db9d5f4bb36b61f7aaf0795eef7ef0120211104135634150.jpg',
#    'category': 'general',
#    'language': 'ar',
#    'country': 'ma',
#    'published_at': '2021-11-04T13:00:00+00:00'}]}

# %% [markdown]
# ## Collect news with specific categories using Python and mediastack (e.g. Business & Technology)

# %%
# Collect business and technology news with Python and mediastack
r2 = requests.get("http://api.mediastack.com/v1/news?access_key=YOUR_ACCESS_KEY&categories=business,technology")

responses2 = r2.json()
responses2
# Out:
# {'pagination': {'limit': 25, 'offset': 0, 'count': 25, 'total': 10000},
#  'data': [{'author': None,
#    'title': 'Immobilien: Furcht vor steigenden Zinsen: Wie Experten das Umfeld für Immobilienanleger beurteilen',
#    'description': 'Eine mögliche Zinswende und weiter steigende Preise könnten für Haus- und Wohnungskäufer zur gefährlichen Mischung werden. Worauf Investoren achten sollten.',
#    'url': 'https://www.handelsblatt.com/finanzen/immobilien/immobilien-furcht-vor-steigenden-zinsen-wie-experten-das-umfeld-fuer-immobilienanleger-beurteilen/27660494.html',
#    'source': 'Handelsblatt',
#    'image': 'https://www.handelsblatt.com/images/immobilien/27670766/2-format2020.jpg',
#    'category': 'business',
#    'language': 'de',
#    'country': 'de',
#    'published_at': '2021-10-02T10:27:06+00:00'},
#   {'author': None,
#    'title': 'iOS 15.01: Update behebt nervigen Bug auf iPhone 13',
#    'description': 'Apple bringt seine mobilen Betriebssysteme auf den neusten Stand und veröffentlicht iOS 15.01 und iPadOS 15.01. Das bringen die frischen Updates für iPhone und iPad!',
#    'url': 'https://www.computerbild.de/artikel/cb-News-Software-iOS-15.01-Update-loest-Problem-iPhone-13-iPadOS-30862357.html',
#    'source': 'computerbild',
#    'image': 'https://i.computer-bild.de/imgs/1/3/9/9/7/1/6/1/320fe3cf068c6390.jpg',
#    'category': 'technology',
#    'language': 'de',
#    'country': 'de',
#    'published_at': '2021-10-04T08:46:00+00:00'},
#   {'author': 'FOCUS Online',
#    'title': 'Fitter mit dem Focus Shopping-Deal - Besser als Fitness-Studio oder Workout-App: Mit VATION bekommen Sie Ihren persönlichen Health-Coach – 6 Wochen kostenlos',
#    'description': 'VATION ist viel mehr als ein Online-Fitness-Tool. Bei VATION hilft Ihnen ein persönlicher Health-Coach, ein gesünderes und damit besseres Leben zu führen. Beratung und Motivation werden hier nicht mit der Gießkanne verteilt: Ernährung, Sport und alle anderen Gesundheitsthemen bespricht Ihr Coach individuell mit Ihnen: Alles zu Ihren Bedingungen, in Ihrem Tempo auf den Ihnen passenden Kommunikationskanälen. Mit Focus bekommen Sie das Ganze 6 Wochen gratis zum ausführlichen Ausprobieren.',
#    'url': 'https://www.focus.de/deals/fitter-mit-dem-focus-shopping-deal-hier-entsteht-ein-super-shopping-deal_id_24304543.html',
#    'source': 'Focus',
#    'image': None,
#    'category': 'technology',
#    'language': 'de',
#    'country': 'de',
#    'published_at': '2021-10-05T08:18:59+00:00'},
#   {'author': None,
#    'title': 'Joachim Olearius: Eigentümerfamilie gibt Führung der Warburg Bank ab',
#    'description': 'Der im Cum-Ex-Skandal belastete Banker verlässt den Vorstand von M.M. Warburg. Künftig kümmert er sich um die unternehmerischen Aktivitäten der Familie Olearius.',
#    'url': 'https://www.handelsblatt.com/finanzen/banken-versicherungen/cum-ex/joachim-olearius-eigentuemerfamilie-gibt-fuehrung-der-warburg-bank-ab/27678514.html',
#    'source': 'Handelsblatt',
#    'image': 'https://www.handelsblatt.com/images/joachim-olearius/27679054/2-format2020.jpg',
#    'category': 'business',
#    'language': 'de',
#    'country': 'de',
#    'published_at': '2021-10-05T11:37:51+00:00'},
#   {'author': None,
#    'title': 'Regierung der Zukunft: Machtvoll, vernetzt, flache Hierarchien: Wie ein Digitalministerium aussehen müsste',
#    'description': 'Die Mehrheit der Wähler wünscht sich ein Digitalministerium, um Deutschlands Technologiedefizite zu beheben. Die\xa0Kommission Forschung und Innovation (EFI) nennt Eckpunkte.\xa0',
#    'url': 'https://www.handelsblatt.com/politik/deutschland/regierung-der-zukunft-machtvoll-vernetzt-flache-hierarchien-wie-ein-digitalministerium-aussehen-muesste-/27678688.html',
#    'source': 'Handelsblatt',
#    'image': 'https://www.handelsblatt.com/images/spd-onlineparteitag/27679768/6-format2020.jpg',
#    'category': 'business',
#    'language': 'de',
#    'country': 'de',
#    'published_at': '2021-10-06T05:02:16+00:00'},
#   {'author': 'Julia Krokoszinski',
#    'title': '7 Security-Todsünden: Wie Salesforce zum Verhängnis wird',
#    'description': 'Salesforce-Systeme sind ein Hort für sensible Kundendaten. Diese Fehler sollten Sie deshalb unbedingt vermeiden. [...]',
#    'url': 'https://computerwelt.at/news/7-security-todsuenden-wie-salesforce-zum-verhaengnis-wird/',
#    'source': 'computerwelt',
#    'image': 'https://computerwelt.at/wp-content/uploads/security-2168233_1920-4.jpg',
#    'category': 'technology',
#    'language': 'de',
#    'country': 'at',
#    'published_at': '2021-10-06T21:40:06+00:00'},
#   {'author': 'Julia Krokoszinski',
#    'title': '5 Schritte zu echter Zero-Trust-Sicherheit',
#    'description': 'Möchten Sie auf Ihrem Weg zu Zero Trust vorankommen? Mit diesen Schritten bleibt Ihre Strategie auf Kurs. [...]',
#    'url': 'https://computerwelt.at/knowhow/5-schritte-zu-echter-zero-trust-sicherheit/',
#    'source': 'computerwelt',
#    'image': 'https://computerwelt.at/wp-content/uploads/stop-634941_1920.jpg',
#    'category': 'technology',
#    'language': 'de',
#    'country': 'at',
#    'published_at': '2021-10-07T05:45:18+00:00'},
#   {'author': None,
#    'title': 'Nordmazedonien – Deutschland: Tipps, Quoten',
#    'description': '8. Spieltag in der WM-Qualifikation, Deutschland trifft in Skopje auf Nordmazedonien: Tipps, Prognosen und Quoten für den 11. Oktober 2021.',
#    'url': 'https://www.computerbild.de/artikel/cb-News-Freizeit-Deutschland-Nordmazedonien-Tipps-Prognosen-Quoten-30898957.html',
#    'source': 'computerbild',
#    'image': 'https://i.computer-bild.de/imgs/1/4/0/0/5/0/4/3/8b9ed9c58403a1e9.jpg',
#    'category': 'technology',
#    'language': 'de',
#    'country': 'de',
#    'published_at': '2021-10-11T13:06:00+00:00'},
#   {'author': None,
#    'title': 'Steuernachlässe: Kampf um Wettbewerbsfähigkeit: Wie Griechenland Fusionen fördern will',
#    'description': 'Keine Volkswirtschaft in der EU hat so viele kleine Firmen wie Griechenland. Mit Steuervergünstigungen für Übernahmen und Kooperationen will die Regierung das nun ändern.',
#    'url': 'https://www.handelsblatt.com/politik/international/steuernachlaesse-kampf-um-wettbewerbsfaehigkeit-wie-griechenland-fusionen-foerdern-will/27695824.html',
#    'source': 'Handelsblatt',
#    'image': 'https://www.handelsblatt.com/images/griechenlands-ministerpraesident-kyriakos-mitsotakis/27695962/2-format2020.jpg',
#    'category': 'business',
#    'language': 'de',
#    'country': 'de',
#    'published_at': '2021-10-11T13:07:55+00:00'},
#   {'author': None,
#    'title': 'Philips-TV: Gut 30 Euro günstiger bei Media Markt',
#    'description': 'Für gemütliche Filmabende: Media Markt hat einen 58-Zoll-TV reduziert im Angebot. Den Philips 58PUS8545/12 sichern Sie sich derzeit günstiger als bei der Konkurrenz.',
#    'url': 'https://www.computerbild.de/artikel/avf-News-Fernseher-Smart-TV-Philips-58PUS8545-12-Media-Markt-Angebot-Deal-30871433.html',
#    'source': 'computerbild',
#    'image': 'https://i.computer-bild.de/imgs/1/3/9/9/9/0/8/5/baba66bbce6897be.jpg',
#    'category': 'technology',
#    'language': 'de',
#    'country': 'de',
#    'published_at': '2021-10-13T04:00:00+00:00'},
#   {'author': 'FOCUS Online',
#    'title': 'Starkes Angebot im o2-Netz - Endlos Datenvolumen samt Allnet-Flat für unter 15 Euro',
#    'description': 'Top-LTE-Tarif im o2-Netz: Mobilcom Debitel bietet mit einer Allnet-Flat mit unbegrenztem Datenvolumen für 14,99 Euro im Monat ein Mega-Schnäppchen. Wir erklären, warum dieses Angebot richtig gut ist.',
#    'url': 'https://www.focus.de/shopping/angebote/nur-noch-bis-11-uhr-buchbar-endlos-datenvolumen-samt-allnet-flat-fuer-unter-15-euro_id_13037593.html',
#    'source': 'Focus',
#    'image': None,
#    'category': 'technology',
#    'language': 'de',
#    'country': 'de',
#    'published_at': '2021-10-01T12:04:47+00:00'},
#   {'author': None,
#    'title': 'Illegales Online-Glücksspiel: Verein will Republik Österreich in Haftung nehmen',
#    'description': 'Der Verein Spielerhilfe" argumentiert damit, dass der Staat zu wenig gegen die Betreiber illegaler Plattformen unternehme.',
#    'url': 'https://www.diepresse.com/6043357/Gluecksspiel_Illegales-OnlineGluecksspiel_Verein-will-Republik?from=rss',
#    'source': 'DiePresse.com',
#    'image': 'https://media.diepresse.com/images/uploads/6/d/d/6043357/Composite-image-of-casino-slot-machine-game-on-mobile-screen-model-released-Symbolfoto-PUBLICATIO_1633444085083548_v0_h.jpg',
#    'category': 'business',
#    'language': 'de',
#    'country': 'at',
#    'published_at': '2021-10-05T14:29:00+00:00'},
#   {'author': 'Julia Krokoszinski',
#    'title': 'DSGVO-Konformität und Schutz des geistigen Eigentums',
#    'description': 'In diesem Whitepaper gehen wir darauf ein, was genau TDA beinhaltet, wie es implementiert werden kann und auf welchen Systemen. Außerdem stellen wir Natuvions Ansatz zur Verwaltung und Entpersonalisierung von Testdaten vor und zeigen die Vorteile für den Kunden. [...]',
#    'url': 'https://computerwelt.at/whitepaper/dsgvo-konformitaet-und-schutz-des-geistigen-eigentums/',
#    'source': 'computerwelt',
#    'image': 'https://computerwelt.at/wp-content/uploads/DSGVO-Konformitaet.png',
#    'category': 'technology',
#    'language': 'de',
#    'country': 'at',
#    'published_at': '2021-10-05T15:42:11+00:00'},
#   {'author': None,
#    'title': 'FamilienunternehmerTUM: Susanne Klatten startet Gründerzentrum für den Mittelstand',
#    'description': 'Die Investorin will zusammen mit Familienunternehmern die Digitalisierung im Mittelstand voranbringen. Das Gründerzentrum hat ein Zehntel des potenziellen Marktes im Visier.',
#    'url': 'https://www.handelsblatt.com/unternehmen/mittelstand/familienunternehmer/familienunternehmertum-susanne-klatten-startet-gruenderzentrum-fuer-den-mittelstand/27683176.html',
#    'source': 'Handelsblatt',
#    'image': 'https://www.handelsblatt.com/images/susanne-klatten/27683606/3-format2020.jpg',
#    'category': 'business',
#    'language': 'de',
#    'country': 'de',
#    'published_at': '2021-10-07T02:12:35+00:00'},
#   {'author': None,
#    'title': 'Prüfers Kolumne: Inflationsprofite mit zwei Laiben Lieken Urkorn',
#    'description': 'Wer denkt schon an Inflation, wenn ein Brot sechs Euro kostet? Vielleicht ist es ein sehr gutes Brot. Letztlich sollte man aber wohl auf Naturalien vertrauen.',
#    'url': 'https://www.handelsblatt.com/meinung/gastbeitraege/pruefers-kolumne-inflationsprofite-mit-zwei-laiben-lieken-urkorn/27683722.html',
#    'source': 'Handelsblatt',
#    'image': 'https://www.handelsblatt.com/images/der-autor/24700406/4-format2020.png',
#    'category': 'business',
#    'language': 'de',
#    'country': 'de',
#    'published_at': '2021-10-09T08:50:30+00:00'},
#   {'author': 'Julia Krokoszinski',
#    'title': 'Erfahren Sie, wie Sie Container in AWS ausführen',
#    'description': 'Dieses E-Book bietet praktische Anweisungen, um schon jetzt mit Containern in AWS zu beginnen. [...]',
#    'url': 'https://computerwelt.at/whitepaper/erfahren-sie-wie-sie-container-in-aws-ausfuehren/',
#    'source': 'computerwelt',
#    'image': 'https://computerwelt.at/wp-content/uploads/Erfahren-Sie-wie-Sie-Container-in-AWS-ausfuehren.png',
#    'category': 'technology',
#    'language': 'de',
#    'country': 'at',
#    'published_at': '2021-10-11T06:14:21+00:00'},
#   {'author': 'Julia Krokoszinski',
#    'title': 'Mit Aruba zum digitalen Krankenhaus',
#    'description': 'Die Anforderungen an die IT im Krankenhaus sind so hoch wie nie zuvor. Interne IT-Abteilungen in Krankenhäusern sind zunehmend gefordert, ihre Expertise einzubringen, um den Service für Patienten zu verbessern und Geschäftsprozesse effizienter zu gestalten. [...]',
#    'url': 'https://computerwelt.at/whitepaper/mit-aruba-zum-digitalen-krankenhaus/',
#    'source': 'computerwelt',
#    'image': 'https://computerwelt.at/wp-content/uploads/Mit-Aruba-zum-digitalen-Krankenhaus.png',
#    'category': 'technology',
#    'language': 'de',
#    'country': 'at',
#    'published_at': '2021-10-11T06:12:10+00:00'},
#   {'author': 'Oliver Weiss',
#    'title': 'Online-Workshop: So machen Sie zuhause Ihren eigenen Käse',
#    'description': 'Gemeinsam mit der Biobäuerin Isabella Bösch-Weiss können Sie in Ihrer eigenen Küche lernen, selber Käse zu machen. [...]',
#    'url': 'https://computerwelt.at/news/online-workshop-so-machen-sie-zuhause-ihren-eigenen-kaese/',
#    'source': 'computerwelt',
#    'image': 'https://computerwelt.at/wp-content/uploads/IMG_20210107_154038.jpg',
#    'category': 'technology',
#    'language': 'de',
#    'country': 'at',
#    'published_at': '2021-10-11T09:50:26+00:00'},
#   {'author': 'Julia Krokoszinski',
#    'title': 'Cloud-Plattformen: 5 Tipps, wie CIOs Abhängigkeiten vermeiden',
#    'description': 'Wer sich nicht von Cloud-Providern wie AWS oder Microsoft abhängig machen will, braucht eine gründliche Analyse und eine Exit-Strategie. [...]',
#    'url': 'https://computerwelt.at/news/cloud-plattformen-5-tipps-wie-cios-abhaengigkeiten-vermeiden/',
#    'source': 'computerwelt',
#    'image': 'https://computerwelt.at/wp-content/uploads/cloud-computing-3669664_1920-1-1.jpg',
#    'category': 'technology',
#    'language': 'de',
#    'country': 'at',
#    'published_at': '2021-10-11T15:55:26+00:00'},
#   {'author': 'Christof Baumgartner',
#    'title': 'Internationaler Award von buildingSMART geht nach Österreich',
#    'description': 'Das vom österreichischen Unternehmen VCE Vienna Consulting Engineers ZT GmbH eingereichte Projekt „From Pixel to Pset – The Digital Structural Inspection“ hat den „buildingSMART International Award" gewonnen. [...]',
#    'url': 'https://computerwelt.at/news/internationaler-award-von-buildingsmart-geht-nach-oesterreich/',
#    'source': 'computerwelt',
#    'image': 'https://computerwelt.at/wp-content/uploads/From_Pixel_to_Pset-Platform_Damage_2095.jpg',
#    'category': 'technology',
#    'language': 'de',
#    'country': 'at',
#    'published_at': '2021-10-13T09:08:50+00:00'},
#   {'author': 'Julia Krokoszinski',
#    'title': 'Minimum Viable Product: 5 Fragen zum MVP',
#    'description': 'Viele Innovationsmethoden und Begriffe aus dem Silicon Valley sind für deutsche Unternehmen Neuland. So auch das Minimum Viable Product. Hier die fünf wichtigsten Fragen dazu - und die Antworten. [...]',
#    'url': 'https://computerwelt.at/news/minimum-viable-product-5-fragen-zum-mvp/',
#    'source': 'computerwelt',
#    'image': 'https://computerwelt.at/wp-content/uploads/mvp_2.png',
#    'category': 'technology',
#    'language': 'de',
#    'country': 'at',
#    'published_at': '2021-10-14T15:37:08+00:00'},
#   {'author': 'Oliver Weiss',
#    'title': 'Hybrid arbeiten: 11 Pflicht-Tools fürs New Normal',
#    'description': 'Hybrid zu arbeiten, liegt im Trend. Diese Tools sind für IT-Profis obligatorisch, um das neue Arbeitsmodell nachhaltig umzusetzen. [...]',
#    'url': 'https://computerwelt.at/knowhow/hybrid-arbeiten-11-pflicht-tools-fuers-new-normal/',
#    'source': 'computerwelt',
#    'image': 'https://computerwelt.at/wp-content/uploads/890x-1-5.webp',
#    'category': 'technology',
#    'language': 'de',
#    'country': 'at',
#    'published_at': '2021-10-19T20:48:00+00:00'},
#   {'author': 'Julia Krokoszinski',
#    'title': 'Windows 11 installieren: So klappt der Umstieg',
#    'description': 'Wer Windows 11 zum Release installieren möchte, braucht die passende Hardware. Bevor Sie einen neuen PC kaufen oder das Update einfach starten, sollten Sie die folgenden Punkte überprüfen. [...]',
#    'url': 'https://computerwelt.at/news/windows-11-installieren-so-klappt-der-umstieg/',
#    'source': 'computerwelt',
#    'image': 'https://computerwelt.at/wp-content/uploads/microsoft-6377157_1920.png',
#    'category': 'technology',
#    'language': 'de',
#    'country': 'at',
#    'published_at': '2021-10-05T14:50:42+00:00'},
#   {'author': None,
#    'title': 'AVM FritzBox 6850 5G im Test: Mittelklasse zum Luxus-Preis',
#    'description': 'Die FritzBox 6850 5G hat zwar schnelles Internet, aber nur eine Mittelklasse-Ausstattung. Kann sie damit die Router-Bestenliste stürmen? Der Test.',
#    'url': 'https://www.computerbild.de/artikel/cb-Tests-DSL-WLAN-AVM-FritzBox-6850-5G-Test-30885175.html',
#    'source': 'computerbild',
#    'image': 'https://i.computer-bild.de/imgs/1/4/0/0/2/0/6/9/1a17ec050f68a8f3.jpg',
#    'category': 'technology',
#    'language': 'de',
#    'country': 'de',
#    'published_at': '2021-10-08T10:16:00+00:00'},
#   {'author': 'Julia Krokoszinski',
#    'title': 'CIO Ralf Oestereich transformiert die SDK',
#    'description': 'Die Süddeutsche Krankenversicherung (SDK) will sich modernisieren. IT-Vorstand Ralf Oestereich setzt dazu eine groß angelegte Strategie um, die Technik und Kultur gleichermaßen wandeln soll. [...]',
#    'url': 'https://computerwelt.at/news/cio-ralf-oestereich-transformiert-die-sdk-2/',
#    'source': 'computerwelt',
#    'image': 'https://computerwelt.at/wp-content/uploads/sdk_2.png',
#    'category': 'technology',
#    'language': 'de',
#    'country': 'at',
#    'published_at': '2021-10-08T15:31:28+00:00'}]}

# %% [markdown]
# ## Collect news with specific language only (e.g. English) using Python and mediastack

# %%
# Collect news that use English with Python and mediastack
r3 = requests.get("http://api.mediastack.com/v1/news?access_key=YOUR_ACCESS_KEY&languages=en")

responses3 = r3.json()
responses3
# Out:
# {'pagination': {'limit': 25, 'offset': 0, 'count': 25, 'total': 10000},
#  'data': [{'author': 'Emma Koehn',
#    'title': 'ASX to follow Wall St higher, Bitcoin at record high',
#    'description': 'ASX to follow Wall St higher, while Bitcoin trades at another record high.',
#    'url': 'https://www.brisbanetimes.com.au/business/markets/asx-to-follow-wall-st-higher-bitcoin-at-record-high-20211020-p591pm.html?ref=rss&utm_medium=rss&utm_source=rss_business',
#    'source': 'brisbanetimes',
#    'image': None,
#    'category': 'general',
#    'language': 'en',
#    'country': 'au',
#    'published_at': '2021-10-20T21:51:46+00:00'},
#   {'author': 'Nick Sestanovich',
#    'title': 'Vacaville Planning Commission will revisit subcommittee discussion',
#    'description': 'The Vacaville Planning Commission unanimously expressed interest in continuing a conversation about establishing subcommittees at its Tuesday meeting.',
#    'url': 'https://www.thereporter.com/2021/10/20/vacaville-planning-commission-will-revisit-subcommittee-discussion/',
#    'source': 'thereporter',
#    'image': 'https://www.thereporter.com/wp-content/uploads/2019/05/Vacaville-City-Hall.jpg?w=1400px&strip=all',
#    'category': 'general',
#    'language': 'en',
#    'country': 'us',
#    'published_at': '2021-10-20T21:55:23+00:00'},
#   {'author': 'S. Florida Times',
#    'title': 'Florida safe house linked to Martin Luther King, preserved',
#    'description': 'St. Augustine, Fla. (AP) &#8211; A house connected to Dr. Martin Luther King Jr. is now in the hands of a couple who plans to ...',
#    'url': 'http://www.sfltimes.com/news/florida-safe-house-linked-to-martin-luther-king-preserved',
#    'source': 'sfltimes',
#    'image': None,
#    'category': 'general',
#    'language': 'en',
#    'country': 'us',
#    'published_at': '2021-10-20T21:56:05+00:00'},
#   {'author': 'S. Florida Times',
#    'title': 'Democrats battling Democrats: Bad',
#    'description': 'The federal government, with Democrat Franklin D. Roosevelt as president, in the 1930s, created the New Deal, bringing a vast network of enhanced social services, ...',
#    'url': 'http://www.sfltimes.com/news/democrats-battling-democrats-bad',
#    'source': 'sfltimes',
#    'image': None,
#    'category': 'general',
#    'language': 'en',
#    'country': 'us',
#    'published_at': '2021-10-20T21:56:05+00:00'},
#   {'author': 'Eric Licas',
#    'title': 'Number of reported anti-Asian hate crimes in LA County jumps up',
#    'description': "There were 44 reported crimes motivated by bias against Asian people in 2020. That's a 76% increase over 2019.",
#    'url': 'https://www.whittierdailynews.com/2021/10/20/number-of-reported-anti-asian-hate-crimes-in-la-county-jumps-up/',
#    'source': 'whittierdailynews',
#    'image': 'https://www.whittierdailynews.com/wp-content/uploads/2021/10/generic-arrest-crime-scene-08.jpg?w=1400px&strip=all',
#    'category': 'general',
#    'language': 'en',
#    'country': 'us',
#    'published_at': '2021-10-20T21:54:09+00:00'},
#   {'author': 'Emma Koehn',
#    'title': 'ASX to follow Wall St higher, Bitcoin at record high',
#    'description': 'ASX to follow Wall St higher, while Bitcoin trades at another record high.',
#    'url': 'https://www.brisbanetimes.com.au/business/markets/asx-to-follow-wall-st-higher-bitcoin-at-record-high-20211020-p591pm.html?ref=rss&utm_medium=rss&utm_source=rss_feed',
#    'source': 'Brisbane Times',
#    'image': None,
#    'category': 'general',
#    'language': 'en',
#    'country': 'au',
#    'published_at': '2021-10-20T21:51:46+00:00'},
#   {'author': 'Eric Licas',
#    'title': 'Number of reported anti-Asian hate crimes in LA County jumps up',
#    'description': "There were 44 reported crimes motivated by bias against Asian people in 2020. That's a 76% increase over 2019.",
#    'url': 'https://www.dailybreeze.com/2021/10/20/number-of-reported-anti-asian-hate-crimes-in-la-county-jumps-up/',
#    'source': 'dailybreeze',
#    'image': 'https://www.dailybreeze.com/wp-content/uploads/2021/10/generic-arrest-crime-scene-08.jpg?w=1400px&strip=all',
#    'category': 'general',
#    'language': 'en',
#    'country': 'us',
#    'published_at': '2021-10-20T21:54:09+00:00'},
#   {'author': 'Roni Caryn Rabin',
#    'title': 'In a First, Surgeons Attached a Pig Kidney to a Human',
#    'description': 'A kidney grown in a genetically altered pig functions normally, scientists reported. The procedure may open the door to a renewable source of desperately needed organs.',
#    'url': 'https://www.nytimes.com/2021/10/19/health/kidney-transplant-pig-human.html',
#    'source': 'The New York Times',
#    'image': 'https://static01.nyt.com/images/2021/10/19/us/19kidney-Montgomery/merlin_196518948_16e96d43-14d1-438c-a050-68adb80820ac-moth.jpg',
#    'category': 'science',
#    'language': 'en',
#    'country': 'us',
#    'published_at': '2021-10-20T21:55:35+00:00'},
#   {'author': None,
#    'title': 'Putin orders most Russians to stay off work for a week as virus deaths rise',
#    'description': 'President Vladimir Putin on Wednesday ordered most Russians to stay off work for a week starting later this month amid rising COVID-19 infections and deaths, and he strongly…',
#    'url': 'https://japantoday.com/category/world/Russians-to-stay-off-work-for-a-week-as-virus-deaths-rise',
#    'source': 'japantoday',
#    'image': None,
#    'category': 'general',
#    'language': 'en',
#    'country': 'us',
#    'published_at': '2021-10-20T21:57:23+00:00'},
#   {'author': 'Joe Teposte',
#    'title': 'AWC celebrates Oktoberfest in its own unique way',
#    'description': 'YUMA, Ariz. (KYMA< KECY) - Celebrated throughout the world for more than two centuries Oktoberfest started in the early 1800s. The celebration is known for its music, its food and of course its beer. The post AWC celebrates Oktoberfest in its own unique way appeared first on KYMA.',
#    'url': 'https://kyma.com/news/kyma-com-category-news-yuma-county/2021/10/20/awc-celebrates-oktoberfest-in-its-own-unique-way/',
#    'source': 'kyma',
#    'image': None,
#    'category': 'general',
#    'language': 'en',
#    'country': 'us',
#    'published_at': '2021-10-20T21:57:43+00:00'},
#   {'author': 'ABMN Staff',
#    'title': 'Telos (TLOS) Tops 24 Hour Volume of $3.78 Million',
#    'description': 'Telos (TLOS) Tops 24 Hour Volume of $3.78 Million',
#    'url': 'https://www.americanbankingnews.com/2021/10/20/telos-tlos-tops-24-hour-volume-of-3-78-million.html',
#    'source': 'americanbankingnews',
#    'image': None,
#    'category': 'general',
#    'language': 'en',
#    'country': 'us',
#    'published_at': '2021-10-20T21:52:42+00:00'},
#   {'author': 'ABMN Staff',
#    'title': 'Rupee Tops One Day Volume of $6.00 (RUP)',
#    'description': 'Rupee Tops One Day Volume of $6.00 (RUP)',
#    'url': 'https://www.americanbankingnews.com/2021/10/20/rupee-tops-one-day-volume-of-6-00-rup.html',
#    'source': 'americanbankingnews',
#    'image': None,
#    'category': 'general',
#    'language': 'en',
#    'country': 'us',
#    'published_at': '2021-10-20T21:50:50+00:00'},
#   {'author': 'ABMN Staff',
#    'title': 'Unistake (UNISTAKE) Price Tops $0.0236 on Exchanges',
#    'description': 'Unistake (UNISTAKE) Price Tops $0.0236 on Exchanges',
#    'url': 'https://www.americanbankingnews.com/2021/10/20/unistake-unistake-price-tops-0-0236-on-exchanges.html',
#    'source': 'americanbankingnews',
#    'image': None,
#    'category': 'general',
#    'language': 'en',
#    'country': 'us',
#    'published_at': '2021-10-20T21:50:48+00:00'},
#   {'author': 'ABMN Staff',
#    'title': 'Blockchain Cuties Universe Governance (BCUG) Price Hits $1.67 on Top Exchanges',
#    'description': 'Blockchain Cuties Universe Governance (BCUG) Price Hits $1.67 on Top Exchanges',
#    'url': 'https://www.americanbankingnews.com/2021/10/20/blockchain-cuties-universe-governance-bcug-price-hits-1-67-on-top-exchanges.html',
#    'source': 'americanbankingnews',
#    'image': None,
#    'category': 'general',
#    'language': 'en',
#    'country': 'us',
#    'published_at': '2021-10-20T21:50:48+00:00'},
#   {'author': 'Susy Campanale',
#    'title': 'Gasperini rues Manchester United save as Atalanta capitulate',
#    'description': 'Gian Piero Gasperini believes the game changed with a David De Gea double save, but Atalanta ‘showed we can have our say’ in the Champions League with their 3-2 loss at Manchester United. La Dea had been leading 2-0 at half-time, despite their injury crisis, with Mario Pasalic and Merih Demiral goals, but losing Demiral [&#8230;]',
#    'url': 'https://football-italia.net/gasperini-rues-manchester-united-save-as-atalanta-capitulate/',
#    'source': 'Football Italia',
#    'image': None,
#    'category': 'sports',
#    'language': 'en',
#    'country': 'it',
#    'published_at': '2021-10-20T21:51:06+00:00'},
#   {'author': 'Zachary Evans',
#    'title': 'F.D.A. Authorizes Moderna and J&J Boosters, Backs ‘Mix-and-Match’',
#    'description': 'A Centers for Disease Control and Prevention will issue recommendations on Thursday regarding which groups should receive boosters.',
#    'url': 'https://www.nationalreview.com/news/f-d-a-authorizes-moderna-and-jj-boosters-backs-mix-and-match/',
#    'source': 'nationalreview',
#    'image': 'https://www.nationalreview.com/wp-content/uploads/2018/06/fda-logo-opioids.jpg?fit=796%2C464',
#    'category': 'general',
#    'language': 'en',
#    'country': 'us',
#    'published_at': '2021-10-20T21:55:47+00:00'},
#   {'author': 'Sam Moore',
#    'title': 'R Kelly was placed on suicide watch after sex crimes conviction',
#    'description': 'Last month, the singer was convicted of nine sex crimes and faces life in prison',
#    'url': 'https://www.independent.co.uk/arts-entertainment/music/news/r-kelly-suicide-sex-crimes-conviction-b1942250.html',
#    'source': 'The Independent',
#    'image': 'https://static.independent.co.uk/2021/08/30/21/newFile.jpg?width=1024&auto=webp',
#    'category': 'general',
#    'language': 'en',
#    'country': 'gb',
#    'published_at': '2021-10-20T21:55:23+00:00'},
#   {'author': 'Tanay Grover',
#    'title': 'Xbox To Announce a Surprise Event For the Fans Very Soon',
#    'description': 'Gaming giant Xbox celebrates its 20th anniversary this November and the surprises for the occasion don&#8217;t seem to end. In recent news, the officials have now seemingly confirmed an anniversary stream intended to celebrate the heritage of the gaming company and its fans. The event will &#8220;look back at 20 years of Xbox&#8221; and what&#8217;s&#8230;The post Xbox To Announce a Surprise Event For the Fans Very Soon appeared first on EssentiallySports.',
#    'url': 'https://www.essentiallysports.com/esports-news-xbox-to-announce-a-surprise-event-for-the-fans-very-soon/',
#    'source': 'Essentially Sports',
#    'image': 'https://image-cdn.essentiallysports.com/wp-content/uploads/how-to-fix-xbox-error-code-0x80072ee7-640x360-1-560x315.jpg',
#    'category': 'sports',
#    'language': 'en',
#    'country': 'us',
#    'published_at': '2021-10-20T21:56:41+00:00'},
#   {'author': 'Rob',
#    'title': 'Bill De Blasio Says Unvaccinated City Workers Cannot Get Paid Leave…',
#    'description': '“Vaccinate. If you choose not to, you have the right to go on unpaid leave.” “We’re not going to pay people unless they’re vaccinated.” Bill de Blasio is a Tyrant. pic.twitter.com/ZPDNlf44J1 &#8212; Benny (@bennyjohnson) October 20, 2021',
#    'url': 'https://www.weaselzippers.us/475568-bill-de-blasio-says-unvaccinated-city-workers-cannot-get-paid-leave/',
#    'source': 'weaselzippers',
#    'image': None,
#    'category': 'general',
#    'language': 'en',
#    'country': 'us',
#    'published_at': '2021-10-20T22:00:38+00:00'},
#   {'author': 'The Ranger',
#    'title': 'Don’t let SAD get you down',
#    'description': 'OPINION By RUTH MARTINEZ Co-Editor\xa0 For as long as I can remember, I have hated cold weather — and don’t get me started on winter [...]',
#    'url': 'https://acranger.com/2021/10/20/dont-let-sad-get-you-down/',
#    'source': 'ac-ranger',
#    'image': None,
#    'category': 'general',
#    'language': 'en',
#    'country': 'us',
#    'published_at': '2021-10-20T22:00:00+00:00'},
#   {'author': 'Andrew Callahan',
#    'title': 'Patriots-Jets injury report: Dont’a Hightower among 16 Pats limited or out Wednesday',
#    'description': "Hightower is dealing with new elbow and ankle injuries, and headlined the Pats' group of four absentees that includes defensive tackle Davon Godchaux and cornerbacks Jonathan Jones and Shaun Wade.",
#    'url': 'https://www.bostonherald.com/2021/10/20/patriots-jets-injury-report-donta-hightower-among-16-pats-limited-or-out-wednesday/',
#    'source': 'bostonherald',
#    'image': 'https://www.bostonherald.com/wp-content/uploads/2021/09/AP21257855250525-e1631795608376.jpg?w=1400px&strip=all',
#    'category': 'general',
#    'language': 'en',
#    'country': 'us',
#    'published_at': '2021-10-20T21:59:15+00:00'},
#   {'author': 'Michael Ginsberg',
#    'title': 'GOP Senator Defends Rahm Emanuel, Says He Will ‘Advocate For America’s Interests’',
#    'description': "'Mayor Emanuel understands this critical circumstance'",
#    'url': 'https://dailycaller.com/2021/10/20/bill-hagerty-japan-ambassador-defends-rahm-emanuel/',
#    'source': 'dailycaller',
#    'image': None,
#    'category': 'general',
#    'language': 'en',
#    'country': 'us',
#    'published_at': '2021-10-20T21:51:23+00:00'},
#   {'author': 'David Hookstead',
#    'title': 'The Crowd For The WNBA Championship Parade Is Laughably Small',
#    'description': 'Nobody seemed to care',
#    'url': 'https://dailycaller.com/2021/10/20/chicago-sky-parade-route-wnba-championship-crowd-size-video/',
#    'source': 'dailycaller',
#    'image': None,
#    'category': 'general',
#    'language': 'en',
#    'country': 'us',
#    'published_at': '2021-10-20T21:55:58+00:00'},
#   {'author': None,
#    'title': 'UAE to host next Club World Cup in early 2022',
#    'description': 'The United Arab Emirates will host the next Club World Cup early in 2022, FIFA president Gianni Infantino announced on Wednesday.The latest edition of the tournament --…',
#    'url': 'https://japantoday.com/category/sports/uae-to-host-next-club-world-cup-in-early-2022',
#    'source': 'japantoday',
#    'image': None,
#    'category': 'general',
#    'language': 'en',
#    'country': 'us',
#    'published_at': '2021-10-20T21:53:51+00:00'},
#   {'author': 'Will Heinrich',
#    'title': 'Revolutionary Model Turned Uncompromising Painter',
#    'description': 'Suzanne Valadon taught herself to paint while modeling for Renoir and Toulouse-Lautrec. A revelatory new survey at the Barnes Collection shows what she learned.',
#    'url': 'https://www.nytimes.com/2021/10/20/arts/design/valadon-painter-barnes-philadelphia.html',
#    'source': 'The New York Times',
#    'image': None,
#    'category': 'entertainment',
#    'language': 'en',
#    'country': 'us',
#    'published_at': '2021-10-20T22:02:27+00:00'}]}

# %% [markdown]
# ## Collect news from specific sources (e.g. BBC) with Python and mediastack

# %%
# Collect news from BBC with Python and mediastack
r4 = requests.get("http://api.mediastack.com/v1/news?access_key=YOUR_ACCESS_KEY&sources=bbc")

responses4 = r4.json()
responses4
# Out:
# {'pagination': {'limit': 25, 'offset': 0, 'count': 25, 'total': 2904},
#  'data': [{'author': None,
#    'title': 'UK agrees free trade deal with New Zealand',
#    'description': 'The government says consumers and businesses will benefit from deal, but it is unlikely to boost growth.',
#    'url': 'https://www.bbc.co.uk/news/business-58988711?at_medium=RSS&at_campaign=KARANGA',
#    'source': 'BBC News - UK Politics',
#    'image': None,
#    'category': 'politics',
#    'language': 'en',
#    'country': 'gb',
#    'published_at': '2021-10-20T22:06:04+00:00'},
#   {'author': None,
#    'title': 'The day a Scottish shopping street exploded',
#    'description': 'Fifty years ago, a row of shops exploded killing 22 people and injuring more than 100, mostly women.',
#    'url': 'https://www.bbc.co.uk/news/uk-scotland-58625427?at_medium=RSS&at_campaign=KARANGA',
#    'source': 'BBC',
#    'image': None,
#    'category': 'general',
#    'language': 'en',
#    'country': 'gb',
#    'published_at': '2021-10-21T01:25:40+00:00'},
#   {'author': None,
#    'title': 'Trump to launch new social media platform TRUTH Social',
#    'description': 'The former US president said it would be used to "stand up to the tyranny of big tech".',
#    'url': 'https://www.bbc.co.uk/news/world-us-canada-58990330?at_medium=RSS&at_campaign=KARANGA',
#    'source': 'BBC',
#    'image': None,
#    'category': 'general',
#    'language': 'en',
#    'country': 'gb',
#    'published_at': '2021-10-21T04:22:06+00:00'},
#   {'author': None,
#    'title': "Elon Musk's Tesla reports record sales and profits",
#    'description': 'The electric car maker recorded its highest quarterly profit of $1.6bn and sold more than 240,000 cars.',
#    'url': 'https://www.bbc.co.uk/news/business-58993848?at_medium=RSS&at_campaign=KARANGA',
#    'source': 'BBC News - Business',
#    'image': None,
#    'category': 'business',
#    'language': 'en',
#    'country': 'gb',
#    'published_at': '2021-10-21T09:27:33+00:00'},
#   {'author': None,
#    'title': 'Nottinghamshire Police investigate 12 reports of needle spiking',
#    'description': 'Police said victims reported effects that were "consistent with a substance being administered".',
#    'url': 'https://www.bbc.co.uk/news/uk-england-nottinghamshire-58990136?at_medium=RSS&at_campaign=KARANGA',
#    'source': 'BBC News - UK',
#    'image': None,
#    'category': 'general',
#    'language': 'en',
#    'country': 'gb',
#    'published_at': '2021-10-21T10:51:00+00:00'},
#   {'author': None,
#    'title': 'Sir David Amess: Ali Harbi Ali charged with murder of MP',
#    'description': 'Prosecutors say Ali Harbi Ali, 25, has been charged with murder and preparing terrorist acts.',
#    'url': 'https://www.bbc.co.uk/news/uk-58997590?at_medium=RSS&at_campaign=KARANGA',
#    'source': 'BBC News - UK',
#    'image': None,
#    'category': 'general',
#    'language': 'en',
#    'country': 'gb',
#    'published_at': '2021-10-21T11:45:38+00:00'},
#   {'author': None,
#    'title': 'Nnamdi Kanu: Nigeria separatist pleads not guilty to terrorism',
#    'description': "Nnamdi Kanu's Indigenous People of Biafra group is viewed as a terror organisation by authorities.",
#    'url': 'https://www.bbc.co.uk/news/world-africa-58997761?at_medium=RSS&at_campaign=KARANGA',
#    'source': 'BBC Africa',
#    'image': None,
#    'category': 'general',
#    'language': 'en',
#    'country': 'gb',
#    'published_at': '2021-10-21T16:00:23+00:00'},
#   {'author': None,
#    'title': 'Newcastle United: Owners hold talks with former Roma boss Paulo Fonseca',
#    'description': "Newcastle United's new owners have held talks with former Roma manager Paulo Fonseca as they continue their search for Steve Bruce's replacement.",
#    'url': 'https://www.bbc.co.uk/sport/football/59000209?at_medium=RSS&at_campaign=KARANGA',
#    'source': 'BBC News',
#    'image': None,
#    'category': 'general',
#    'language': 'en',
#    'country': 'gb',
#    'published_at': '2021-10-21T17:11:11+00:00'},
#   {'author': None,
#    'title': 'Michael Gove: No 10 condemns anti-lockdown protesters over confrontation',
#    'description': 'Video footage online appears to show Housing Secretary Michael Gove being harangued by protesters.',
#    'url': 'https://www.bbc.co.uk/news/uk-politics-58973595?at_medium=RSS&at_campaign=KARANGA',
#    'source': 'BBC News - UK',
#    'image': None,
#    'category': 'general',
#    'language': 'en',
#    'country': 'gb',
#    'published_at': '2021-10-19T17:37:42+00:00'},
#   {'author': None,
#    'title': 'Calls for nightclub searches after Nottingham needle spiking reports',
#    'description': 'A student who believes she was jabbed in a club says she has been left feeling "really scared".',
#    'url': 'https://www.bbc.co.uk/news/uk-england-nottinghamshire-58977839?at_medium=RSS&at_campaign=KARANGA',
#    'source': 'BBC',
#    'image': None,
#    'category': 'general',
#    'language': 'en',
#    'country': 'gb',
#    'published_at': '2021-10-20T09:30:23+00:00'},
#   {'author': None,
#    'title': 'Lord Janner: Police shut down MP child abuse investigations - report',
#    'description': 'An inquiry finds police seemed "reluctant to investigate" claims against former MP Lord Janner.',
#    'url': 'https://www.bbc.co.uk/news/uk-england-leicestershire-58932593?at_medium=RSS&at_campaign=KARANGA',
#    'source': 'BBC',
#    'image': None,
#    'category': 'general',
#    'language': 'en',
#    'country': 'gb',
#    'published_at': '2021-10-19T13:33:02+00:00'},
#   {'author': None,
#    'title': 'Back to school: How are pupils being kept Covid-safe?',
#    'description': 'Face coverings remain compulsory in Scottish schools, and are being reintroduced in parts of England.',
#    'url': 'https://www.bbc.co.uk/news/education-51643556?at_medium=RSS&at_campaign=KARANGA',
#    'source': 'BBC News - Family & Education',
#    'image': None,
#    'category': 'general',
#    'language': 'en',
#    'country': 'gb',
#    'published_at': '2021-10-19T13:31:23+00:00'},
#   {'author': None,
#    'title': "Little Amal: Jude Law welcomes War Horse creators' refugee puppet",
#    'description': 'Jude Law greets the giant puppet of a Syrian refugee child at the last stage of her 5,000km trek.',
#    'url': 'https://www.bbc.co.uk/news/entertainment-arts-58965390?at_medium=RSS&at_campaign=KARANGA',
#    'source': 'BBC News - Entertainment & Arts',
#    'image': None,
#    'category': 'entertainment',
#    'language': 'en',
#    'country': 'gb',
#    'published_at': '2021-10-19T14:36:21+00:00'},
#   {'author': None,
#    'title': 'Karim Benzema: French sex tape blackmail case trial starts',
#    'description': 'The Real Madrid footballer is accused of complicity in an attempt to blackmail Mathieu Valbuena.',
#    'url': 'https://www.bbc.co.uk/news/world-europe-58977550?at_medium=RSS&at_campaign=KARANGA',
#    'source': 'BBC News - World',
#    'image': None,
#    'category': 'general',
#    'language': 'en',
#    'country': 'gb',
#    'published_at': '2021-10-20T16:05:40+00:00'},
#   {'author': None,
#    'title': 'Fears over the future of free debt advice',
#    'description': 'There is growing concern that free face-to-face debt advice could be cut.',
#    'url': 'https://www.bbc.co.uk/news/business-58993223?at_medium=RSS&at_campaign=KARANGA',
#    'source': 'BBC News - Business',
#    'image': None,
#    'category': 'business',
#    'language': 'en',
#    'country': 'gb',
#    'published_at': '2021-10-21T23:01:45+00:00'},
#   {'author': None,
#    'title': 'Woman shot dead on set of new Alec Baldwin movie Rust',
#    'description': 'A man is also being treated in hospital during the accidental shooting at a film set in New Mexico.',
#    'url': 'https://www.bbc.co.uk/news/world-us-canada-59005500?at_medium=RSS&at_campaign=KARANGA',
#    'source': 'BBC News - Entertainment & Arts',
#    'image': None,
#    'category': 'entertainment',
#    'language': 'en',
#    'country': 'gb',
#    'published_at': '2021-10-22T02:46:32+00:00'},
#   {'author': None,
#    'title': 'UK shop sales continue to fall in September',
#    'description': 'Retail sales in the UK fell for the fifth month in a row, according to the Office for National Statistics.',
#    'url': 'https://www.bbc.co.uk/news/business-59006619?at_medium=RSS&at_campaign=KARANGA',
#    'source': 'BBC',
#    'image': None,
#    'category': 'general',
#    'language': 'en',
#    'country': 'gb',
#    'published_at': '2021-10-22T06:51:37+00:00'},
#   {'author': None,
#    'title': 'Piers Morgan leaves ITV show Life Stories, with Kate Garraway taking over',
#    'description': "The presenter's final guest will be Kate Garraway, who will then take over hosting duties.",
#    'url': 'https://www.bbc.co.uk/news/entertainment-arts-59007455?at_medium=RSS&at_campaign=KARANGA',
#    'source': 'BBC News - Entertainment & Arts',
#    'image': None,
#    'category': 'entertainment',
#    'language': 'en',
#    'country': 'gb',
#    'published_at': '2021-10-22T09:45:35+00:00'},
#   {'author': None,
#    'title': 'Ex-Labour MP Frank Field is dying, peer reveals',
#    'description': 'A statement from the veteran politician was read out in the Lords, backing a new assisted dying bill.',
#    'url': 'https://www.bbc.co.uk/news/uk-politics-59009053?at_medium=RSS&at_campaign=KARANGA',
#    'source': 'BBC News - UK',
#    'image': None,
#    'category': 'general',
#    'language': 'en',
#    'country': 'gb',
#    'published_at': '2021-10-22T11:51:42+00:00'},
#   {'author': None,
#    'title': 'Crime-hit Chicago grapples with police vaccine revolt',
#    'description': 'Vaccination rates have lagged among US police, even as Covid becomes their leading cause of death.',
#    'url': 'https://www.bbc.co.uk/news/world-us-canada-58989555?at_medium=RSS&at_campaign=KARANGA',
#    'source': 'BBC',
#    'image': None,
#    'category': 'general',
#    'language': 'en',
#    'country': 'gb',
#    'published_at': '2021-10-22T13:20:20+00:00'},
#   {'author': None,
#    'title': 'Two men arrested in Nottingham needle spiking investigation',
#    'description': 'The arrests follow multiple reports of drinks being spiked and needles being used.',
#    'url': 'https://www.bbc.co.uk/news/uk-england-nottinghamshire-59011522?at_medium=RSS&at_campaign=KARANGA',
#    'source': 'BBC News',
#    'image': None,
#    'category': 'general',
#    'language': 'en',
#    'country': 'gb',
#    'published_at': '2021-10-22T13:50:56+00:00'},
#   {'author': None,
#    'title': 'Portsmouth: Two people seriously injured in house explosion',
#    'description': 'Five fire crews are on the scene of a blaze which sent smoke over the surrounding area.',
#    'url': 'https://www.bbc.co.uk/news/uk-england-hampshire-59013899?at_medium=RSS&at_campaign=KARANGA',
#    'source': 'BBC News - UK',
#    'image': None,
#    'category': 'general',
#    'language': 'en',
#    'country': 'gb',
#    'published_at': '2021-10-22T15:00:45+00:00'},
#   {'author': None,
#    'title': "World Track Cycling Championships: GB's Katie Archibald wins omnium title",
#    'description': "Katie Archibald wins Great Britain's first gold medal at this year's World Championships after securing a clean sweep in the women's omnium.",
#    'url': 'https://www.bbc.co.uk/sport/cycling/59016389?at_medium=RSS&at_campaign=KARANGA',
#    'source': 'BBC',
#    'image': None,
#    'category': 'general',
#    'language': 'en',
#    'country': 'gb',
#    'published_at': '2021-10-22T20:26:21+00:00'},
#   {'author': None,
#    'title': "Covid: 'Fake strays' surge post-lockdown sees more dogs put down",
#    'description': 'Some lockdown pet owners pretend dogs are genuine strays after trying to sell them, rescuers say.',
#    'url': 'https://www.bbc.co.uk/news/uk-wales-59008703?at_medium=RSS&at_campaign=KARANGA',
#    'source': 'BBC',
#    'image': None,
#    'category': 'general',
#    'language': 'en',
#    'country': 'gb',
#    'published_at': '2021-10-23T06:06:52+00:00'},
#   {'author': None,
#    'title': 'Wiltshire man jailed for historic rape after DNA breakthrough',
#    'description': 'Kenneth Wells, who raped and imprisoned a 71-year-old, was prosecuted thanks to DNA advances.',
#    'url': 'https://www.bbc.co.uk/news/uk-england-wiltshire-58752034?at_medium=RSS&at_campaign=KARANGA',
#    'source': 'BBC News',
#    'image': None,
#    'category': 'general',
#    'language': 'en',
#    'country': 'gb',
#    'published_at': '2021-10-04T13:02:45+00:00'}]}

# %% [markdown]
# ## Collect hundreds of news or more with Python and mediastack

# %%
# Collect 100 of news from BBC with Python and mediastack
r5 = requests.get("http://api.mediastack.com/v1/news?access_key=YOUR_ACCESS_KEY&limit=100")

responses5 = r5.json()
responses5
# Out:
# {'pagination': {'limit': 100, 'offset': 0, 'count': 100, 'total': 10000},
#  'data': [{'author': 'Hala Abdallah',
#    'title': 'Taliban says its purge of officials unrelated to sanctioned ministers\xa0',
#    'description': 'The Taliban appointed ministers sanctioned by the US in its interim government. The Taliban has refused calls by the international community to remove ministers from its interim government under US and UN sanction threats, a senior official said according to a Sputnik report. In comments made to the Russian outlet, Taliban Spokesman Mohammad Naeem confirmed [&#8230;](The post Taliban says its purge of officials unrelated to sanctioned ministers\xa0 is from Doha News | Qatar.)',
#    'url': 'http://feedproxy.google.com/~r/DohaNews/~3/_3OlD8mmIAA/',
#    'source': 'Doha News',
#    'image': None,
#    'category': 'general',
#    'language': 'ar',
#    'country': 'qa',
#    'published_at': '2021-10-13T13:15:39+00:00'},
#   {'author': None,
#    'title': 'Le Polisario menace de «poursuivre la guerre» si «l’ONU continue de gérer la crise au lieu de la solutionner»',
#    'description': 'Alors que le conseil de sécurité examine, en ce mois d’octobre, la prolongation du mandat de la MINURSO au Sahara, le Front Polisario choisit de hausser le ton contre l’ONU. Mardi, son secrétaire général a affirmé que «la guerre est déclenchée sur le terrain et il n’est plus possible d’éviter ses risques et retombées sur la région, au cas où l’ONU continue de gérer la crise au lieu de la solutionner».',
#    'url': 'https://www.yabiladi.com/articles/details/117423/polisario-menace-poursuivre-guerre-l-onu.html',
#    'source': 'yabiladi.com',
#    'image': 'https://static.yabiladi.com/files/articles/bae736dfc95dbac510fe11ea0d82162d20211013150259150.jpg',
#    'category': 'general',
#    'language': 'ar',
#    'country': 'ma',
#    'published_at': '2021-10-13T13:20:00+00:00'},
#   {'author': 'إعلام',
#    'title': 'بعد تعافيه من كورونا.. محمد مصطفى شردي يشكر هؤلاء - E3lam.Com',
#    'description': 'وجّه الإعلامي محمد مصطفى شردي الشكر لزملائه داخل فريق عمل قناة الحياة، بعد تعافيه من الإصابة بفيروس كورونا مؤخرا',
#    'url': 'http://thinakhbarak.local/articles/42844774-%D8%A8%D8%B9%D8%AF-%D8%AA%D8%B9%D8%A7%D9%81%D9%8A%D9%87-%D9%85%D9%86-%D9%83%D9%88%D8%B1%D9%88%D9%86%D8%A7-%D9%85%D8%AD%D9%85%D8%AF-%D9%85%D8%B5%D8%B7%D9%81%D9%89-%D8%B4%D8%B1%D8%AF%D9%8A-%D9%8A%D8%B4%D9%83%D8%B1',
#    'source': 'Akhbarak.net',
#    'image': 'https://akhbarak.net/photos/articles-photos/2021/10/13/42844774/42844774-large.jpg?1634128595',
#    'category': 'general',
#    'language': 'ar',
#    'country': 'eg',
#    'published_at': '2021-10-13T12:36:30+00:00'},
#   {'author': 'Menatalla Ibrahim',
#    'title': 'Katara extends deadline for ‘Language in Holy Quran’ research competition',
#    'description': 'The first place winner will have the chance to win $30,000.\xa0 The Cultural Village Foundation (Katara) has extended the deadline for its ‘Language in the Holy Quran’ competition, the institution announced. The date has been extended for one month to 13 November at the request of participants who petitioned the competition committee, Katara added. The [&#8230;](The post Katara extends deadline for &#8216;Language in Holy Quran&#8217; research competition is from Doha News | Qatar.)',
#    'url': 'http://feedproxy.google.com/~r/DohaNews/~3/UPXu3uScMHI/',
#    'source': 'Doha News',
#    'image': None,
#    'category': 'general',
#    'language': 'ar',
#    'country': 'qa',
#    'published_at': '2021-10-12T13:45:11+00:00'},
#   {'author': None,
#    'title': "Fès : Sept arrestations dans une affaire de pratique d'avortement",
#    'description': 'La brigade régionale de la police judiciaire de Fès a ouvert, mardi, une enquête judiciaire sous la supervision du parquet compétent pour déterminer les actes criminels reprochés à sept individus, pour leur implication présumée de pratique régulière davortement, de falsification, de détournement dun mineur, dattentat à la pudeur, et de participation à la perpétration de ces actes criminels.',
#    'url': 'https://www.yabiladi.com/articles/details/117367/sept-arrestations-dans-affaire-pratique.html',
#    'source': 'yabiladi.com',
#    'image': 'https://static.yabiladi.com/files/articles/2d3ab45674f2456b84b28403db47704420211013120421150.jpg',
#    'category': 'general',
#    'language': 'ar',
#    'country': 'ma',
#    'published_at': '2021-10-13T10:20:00+00:00'},
#   {'author': None,
#    'title': 'بعد تلبية طلبه والترحيب به في &quot;ملاعب المملكة&quot;.. المدير التقني لمنتخب غينيا بيساو يصرح: &quot;التأهل صعب للغاية لأن المغرب سيلعب 5 مباريات من أصل 6 على أرضه&quot;',
#    'description': 'يرى المدير التقني لمنتخب غينيا بيساو، غويليرم فارينيا، أن منافسة بلاده للمغرب في المجموعة التاسعة لـ"تصفيات المونديال" لم تكن ممكنة، متحدثًا عن الفوارق الكبيرة بين المنتخبين والظروف التي أقيمت فيها مر',
#    'url': 'http://www.elbotola.com/article/2021-10-12-11-47-285.html',
#    'source': 'Elbotola.com',
#    'image': None,
#    'category': 'general',
#    'language': 'ar',
#    'country': 'ma',
#    'published_at': '2021-10-12T12:35:31+00:00'},
#   {'author': None,
#    'title': 'Affaire Ghali : Les députés rejettent la création d’une commission d’enquête parlementaire',
#    'description': 'La majorité gouvernementale en Espagne a rejeté la création d’une commission d’enquête parlementaire sur les circonstances de l’entrée de Brahim Ghali. Le bureau de la Chambre des représentants a voté contre une proposition du Parti Populaire.\xa0Une initiative qui n’a eu l’adhésion que du groupe de Vox.',
#    'url': 'https://www.yabiladi.com/articles/details/117469/affaire-ghali-deputes-rejettent-creation.html',
#    'source': 'yabiladi.com',
#    'image': 'https://static.yabiladi.com/files/articles/f4c621f12360501121e9462bab4222a020211013181528150.jpg',
#    'category': 'general',
#    'language': 'ar',
#    'country': 'ma',
#    'published_at': '2021-10-13T17:00:00+00:00'},
#   {'author': None,
#    'title': 'Le Royaume-Uni attend la première cargaison de fret depuis le Maroc par la route «Brexit buster»',
#    'description': 'La première cargaison de fret maritime entre le Maroc et le Royaume-Uni utilisant la nouvelle route «Brexit buster» est sur le point d’être réalisée avec l’arrivée à Poole en Angleterre de fruits et légumes biologiques de saison en provenance de Tanger.',
#    'url': 'https://www.yabiladi.com/articles/details/117380/royaume-uni-attend-premiere-cargaison-fret.html',
#    'source': 'yabiladi.com',
#    'image': 'https://static.yabiladi.com/files/articles/235bc43a6ab6c6993c33315587c74f4120211013131929150.jpg',
#    'category': 'general',
#    'language': 'ar',
#    'country': 'ma',
#    'published_at': '2021-10-13T11:37:00+00:00'},
#   {'author': None,
#    'title': 'نيمار عن &#x27;أسوأ لحظة في مسيرته&#x27;: &quot;كنت قريبا من عدم القدرة على المشي من جديد&quot;!',
#    'description': 'عاش النجم البرازيلي نيمار جونيور، "أسوأ اللحظات في مسيرته"، خلال مشاركته في كأس العالم 2014 الذي احتضنته بلاده، حينها تعرض لإصابة خطيرة على مستوى الظهر، كادت أن تنهي مشواره الكروي مبكرا.وخلال "فيلم وث',
#    'url': 'http://www.elbotola.com/article/2021-10-13-16-19-457.html',
#    'source': 'Elbotola.com',
#    'image': None,
#    'category': 'general',
#    'language': 'ar',
#    'country': 'ma',
#    'published_at': '2021-10-13T16:25:32+00:00'},
#   {'author': None,
#    'title': 'بعد السنغال.. المنتخب المغربي ثاني المتأهلين لـ&quot;الدور الفاصل&quot; من تصفيات مونديال &quot;قطر 2022&quot;',
#    'description': 'أضحى المنتخب المغربي لكرة القدم، ثاني المتأهلين للدور الفاصل من التصفيات الأفريقية لمونديال "قطر 2022"، عقب انتصاره على غينيا بأربعة أهداف مقابل واحد، في المواجهة التي جرت على البساط الأخضر لـ"المركب',
#    'url': 'http://www.elbotola.com/article/2021-10-12-22-33-286.html',
#    'source': 'Elbotola.com',
#    'image': None,
#    'category': 'general',
#    'language': 'ar',
#    'country': 'ma',
#    'published_at': '2021-10-12T22:40:31+00:00'},
#   {'author': 'Menatalla Ibrahim',
#    'title': 'This Qatari startup is going to the Hult Prize finals for a $1mn prize',
#    'description': 'The global competition offers a $1,000,000 prize.\xa0 For the first time in history, a Qatari startup has qualified for the world&#8217;s largest startup programme, the Hult Prize competition, marking a significant milestone for entrepreneurs in the Gulf state. Held annually, the Hult Prize is a year-long competition that aims to transform how youth envision their [&#8230;](The post This Qatari startup is going to the Hult Prize finals for a $1mn prize is from Doha News | Qatar.)',
#    'url': 'http://feedproxy.google.com/~r/DohaNews/~3/IWI_vs5-Qyg/',
#    'source': 'Doha News',
#    'image': None,
#    'category': 'general',
#    'language': 'ar',
#    'country': 'qa',
#    'published_at': '2021-10-27T09:28:07+00:00'},
#   {'author': None,
#    'title': 'Sahara : L’Irlande dément une «réduction» de son engagement auprès de l’ONU',
#    'description': 'Le ministère irlandais de la Défense a démenti, dimanche, une «réduction» de l’engagement de l’Irlande auprès de l’ONU, après le retrait de casques bleus irlandais mobilisés jusqu’ici dans la mission des Nations Unies du Sahara occidental (MINURSO). Selon Irish Examiner, les membres militaires irlandais faisaient partie du contingent de la mission jusquen juillet dernier.',
#    'url': 'https://www.yabiladi.com/articles/details/119414/sahara-l-irlande-dement-reduction-engagement.html',
#    'source': 'yabiladi.com',
#    'image': 'https://static.yabiladi.com/files/articles/5df5f1249de06f489446bb339f19f2f920211026183008150.jpg',
#    'category': 'general',
#    'language': 'ar',
#    'country': 'ma',
#    'published_at': '2021-10-26T17:08:00+00:00'},
#   {'author': None,
#    'title': '&quot;الكورفا سود&quot;: &quot;الرئيس الجديد مسؤول عن إعادة الثقة بين المسيرين والجماهير وبناء نموذج النادي القائم بذاته&quot;',
#    'description': 'أكدت "الكورفا سود"، المساندة للرجاء الرياضي، أن المنخرطين لهم كامل الصلاحية في التصويت على المرشح "الأصلح" في نظرهم لرئاسة الفريق خلال الفترة المقبلة، مؤكدة أن الجماهير من حقها تحميلهم مسؤولية اختياره',
#    'url': 'http://www.elbotola.com/article/2021-10-27-13-07-471.html',
#    'source': 'Elbotola.com',
#    'image': None,
#    'category': 'general',
#    'language': 'ar',
#    'country': 'ma',
#    'published_at': '2021-10-27T13:20:31+00:00'},
#   {'author': None,
#    'title': '&quot;الكاف&quot; ينفي تأجيل أو إلغاء كأس أمم أفريقيا &quot;الكاميرون 2021&quot; ويؤكد مناقشته إمكانية &quot;الحضور الجماهيري&quot;',
#    'description': 'نفى الاتحاد الأفريقي لكرة القدم، كل الأنباء التي تروج بخصوص نيته تأجيل أو إلغاء مسابقة كأس أمم أفريقيا لكرة القدم، والمزمع تنظيمها من التاسع يناير وحتى السادس من فبراير المقبلين.وكانت اللجنة التنفيذية',
#    'url': 'http://www.elbotola.com/article/2021-10-26-17-35-116.html',
#    'source': 'Elbotola.com',
#    'image': None,
#    'category': 'general',
#    'language': 'ar',
#    'country': 'ma',
#    'published_at': '2021-10-26T17:40:33+00:00'},
#   {'author': None,
#    'title': 'إعلامي فرنسي يَشُنّ هجوماً &quot;شنيعاً&quot; على حكيمي: &quot;أشرف اعتاد الحياة الباريسية.. سيغرق إذا لم يتمالك نفسه&quot;',
#    'description': 'هاجم الإعلامي الفرنسي، دانييل ريولو، بحدة، المغربي أشرف حكيمي، بعد التعادل الذي اكتفى به باريس سان جيرمان أمام أولمبيك مارسيليا، أول أمس الأحد، لحساب الجولة الـ11 من دوري الدرجة الأولى الفرنسي، مُعتبر',
#    'url': 'http://www.elbotola.com/article/2021-10-26-21-55-267.html',
#    'source': 'Elbotola.com',
#    'image': None,
#    'category': 'general',
#    'language': 'ar',
#    'country': 'ma',
#    'published_at': '2021-10-26T22:00:33+00:00'},
#   {'author': None,
#    'title': 'بعد خسارة &quot;الكلاسيكو&quot;.. برشلونة ينهزم ضد رايو فايكانو بهدف &quot;النَّمر&quot; فالكاو',
#    'description': 'تعرض إف سي برشلونة مساء يومه الأربعاء، لهزيمة جديدة في الدوري الإسباني، وسقط بهدف نظيف أمام مضيفه رايو فايكانو (1-0)، برسم الجولة الحادية عشر.ودخل المدرب رونالد كومان هذه المواجهة، بتشكيلة يقودها الأر',
#    'url': 'http://www.elbotola.com/article/2021-10-27-18-39-3.html',
#    'source': 'Elbotola.com',
#    'image': None,
#    'category': 'general',
#    'language': 'ar',
#    'country': 'ma',
#    'published_at': '2021-10-27T18:55:34+00:00'},
#   {'author': None,
#    'title': 'بايرن ميونيخ &quot;يُهان&quot; ضد بوروسيا مونشنغلادباخ بهزيمة &quot;ثقيلة&quot; (5-0) ويودع كأس ألمانيا',
#    'description': 'حقق بوروسيا مونشنغلادباخ مساء يومه الأربعاء، "مفاجأة" من العيار الثقيل، بعد أن تغلب على "العملاق" بايرن ميونيخ، بخماسية نظيفة (5-0)، في مباراة برسم الدور الثاني من كأس ألمانيا.ودخل "البافاري" هذه المب',
#    'url': 'http://www.elbotola.com/article/2021-10-27-20-37-271.html',
#    'source': 'Elbotola.com',
#    'image': None,
#    'category': 'general',
#    'language': 'ar',
#    'country': 'ma',
#    'published_at': '2021-10-27T20:40:35+00:00'},
#   {'author': None,
#    'title': 'Les circonvolutions de l’Algérie pour livrer du gaz à l’Espagne en évitant le Maroc',
#    'description': 'Alors que la ministre espagnole de la Transition écologique est à Alger, les autorités algérienne avance une nouvelle piste pour répondre aux besoins en gaz de l’Espagne.',
#    'url': 'https://www.yabiladi.com/articles/details/119604/circonvolutions-l-algerie-pour-livrer-l-espagne.html',
#    'source': 'yabiladi.com',
#    'image': 'https://static.yabiladi.com/files/articles/1a7f384c38c095c8aee3d605b7e3dae120211027183120150.png',
#    'category': 'general',
#    'language': 'ar',
#    'country': 'ma',
#    'published_at': '2021-10-27T17:00:00+00:00'},
#   {'author': None,
#    'title': "Tanger : Un ouvrier blessé dans l'effondrement partiel d'un chantier",
#    'description': 'Un ouvrier a été légèrement blessé mardi dans leffondrement partiel dun chantier de construction au niveau de lavenue Youssef Ben Tachefine à Tanger, apprend-on auprès de la wilaya de la région Tanger-Tétouan-Al Hoceima.',
#    'url': 'https://www.yabiladi.com/articles/details/119453/tanger-ouvrier-blesse-dans-l-effondrement.html',
#    'source': 'yabiladi.com',
#    'image': 'https://static.yabiladi.com/files/articles/3bfe5091b7722dbd65dde36869b336b620211027101732150.jpg',
#    'category': 'general',
#    'language': 'ar',
#    'country': 'ma',
#    'published_at': '2021-10-27T08:19:00+00:00'},
#   {'author': 'monjed jado',
#    'title': 'Palestinian Rights Committee’s Bureau Expresses Deep Concern at Israel’s Designation of Civil Society Bodies as “Terrorist Organizations”',
#    'description': 'Bethlehem/PNN/ The Bureau of the Committee on the Exercise of the Inalienable Rights of the Palestinian People expresses its deep concern at Israel&#8217;s decision of 22 October to designate six human rights and humanitarian Palestinian civil society organizations, ie, Addameer Prisoner Support and Human Rights Association; Al Haq; Defense for Children International &#8211; Palestine; Union &#8230;التدوينة Palestinian Rights Committee’s Bureau Expresses Deep Concern at Israel’s Designation of Civil Society Bodies as &#8220;Terrorist Organizations&#8221...',
#    'url': 'http://english.pnn.ps/2021/11/05/palestinian-rights-committees-bureau-expresses-deep-concern-at-israels-designation-of-civil-society-bodies-as-terrorist-organizations-2/',
#    'source': 'english',
#    'image': None,
#    'category': 'general',
#    'language': 'ar',
#    'country': 'ps',
#    'published_at': '2021-11-05T11:38:36+00:00'},
#   {'author': 'إعلام',
#    'title': 'هذا الأسبوع.. نجلاء بدر تنافس خالد الصاوي في "هزر فزر مع لولي" - E3lam.Com',
#    'description': 'يحل عدد من نجوم الفن ضيوفا على برنامج "هزر فزر مع لولي" الذي تقدمه الفنانة ليلى زاهر، يومي السبت والأحد، 6 و7 نوفمبر الجاري، على قناة cbc',
#    'url': 'http://thinakhbarak.local/articles/42978784-%D9%87%D8%B0%D8%A7-%D8%A7%D9%84%D8%A3%D8%B3%D8%A8%D9%88%D8%B9-%D9%86%D8%AC%D9%84%D8%A7%D8%A1-%D8%A8%D8%AF%D8%B1-%D8%AA%D9%86%D8%A7%D9%81%D8%B3-%D8%AE%D8%A7%D9%84%D8%AF-%D8%A7%D9%84%D8%B5%D8%A7%D9%88%D9%8A',
#    'source': 'Akhbarak.net',
#    'image': 'https://akhbarak.net/photos/articles-photos/2021/11/4/42978784/42978784-large.jpg?1636041091',
#    'category': 'general',
#    'language': 'ar',
#    'country': 'eg',
#    'published_at': '2021-11-04T15:51:25+00:00'},
#   {'author': None,
#    'title': "Maroc-Algérie : L'Espagne dit suivre «avec inquiétude» les derniers événements au Maghreb",
#    'description': 'Le ministre espagnol des Affaires étrangères, de lUE et de la coopération a reconnu, ce mercredi, que le gouvernement de son pays suit «avec inquiétude» les derniers événements au Maghreb, après que lAlgérie a accusé le Maroc davoir tué trois\xa0camionneurs algériens. Dans une déclaration au Congrès des députés, reprise par Europa Press, José Manuel Albares a assuré quil travaillera à éviter «une escalade» entre les deux pays, qu’il a qualifiés de «partenaires stratégiques» de lEspagne.',
#    'url': 'https://www.yabiladi.com/articles/details/120684/maroc-algerie-l-espagne-suivre-avec-inquietude.html',
#    'source': 'yabiladi.com',
#    'image': 'https://static.yabiladi.com/files/articles/e53a2c231f98813f662ca49bb3e4c4e520211104151747150.jpg',
#    'category': 'general',
#    'language': 'ar',
#    'country': 'ma',
#    'published_at': '2021-11-04T14:27:00+00:00'},
#   {'author': 'monjed jado',
#    'title': 'JPS & IFJ says considering an ICC case over Israel’s systematic targeting of Palestinian journalists',
#    'description': 'Ramallah/PNN/Monjed Jadou The International Federation of Journalists (IFJ) and Palestinian Journalists Syndicate (JPS) In cooperation with Palestinian and international rights groups are preparing to lodge an International Criminal Court (ICC) complaint against Israel over its “systematic targeting” of Palestinian journalists in Gaza, IFJ has said in a press release. Journalists&#8217; representative in the Palestinian Journalists &#8230;التدوينة JPS & IFJ says considering an ICC case over Israel&#8217;s systematic targeting of Palestinian journalists ظهرت أولاً على PNN...',
#    'url': 'http://english.pnn.ps/2021/11/05/jps-ifj-says-considering-an-icc-case-over-israels-systematic-targeting-of-palestinian-journalists/',
#    'source': 'english',
#    'image': None,
#    'category': 'general',
#    'language': 'ar',
#    'country': 'ps',
#    'published_at': '2021-11-05T12:04:24+00:00'},
#   {'author': 'ICT Business',
#    'title': 'Cairo ICT….محطات ونجاحات على مدار 25 عام - ICT Business Magazine - أي سي تي بيزنس',
#    'description': 'يحتفل هذا العام معرض القاهرة الدولي للتكنولوجياCairo ICT \xa0باليوبيل الفضى وسط تأكيد من عدد من الشركات',
#    'url': 'http://thinakhbarak.local/articles/42982988-Cairo-ICT-%D9%85%D8%AD%D8%B7%D8%A7%D8%AA-%D9%88%D9%86%D8%AC%D8%A7%D8%AD%D8%A7%D8%AA-%D8%B9%D9%84%D9%89-%D9%85%D8%AF%D8%A7%D8%B1-25-%D8%B9%D8%A7%D9%85--',
#    'source': 'Akhbarak.net',
#    'image': 'https://akhbarak.net/photos/articles-photos/2021/11/5/42982988/42982988-large.jpg?1636111270',
#    'category': 'general',
#    'language': 'ar',
#    'country': 'eg',
#    'published_at': '2021-11-05T11:21:06+00:00'},
#   {'author': None,
#    'title': 'Affaires des camionneurs algériens : Des éléments de la MINURSO sur le lieu de l’incident',
#    'description': 'Une équipe de la MINURSO se sont rendus, ce jeudi, sur le lieu où les trois camionneurs algériens ont trouvé la mort dans des conditions non-encore élucidées.\xa0L’envoi d’éléments de la mission onusienne atteste que l’incident s’est produit à l’Est du mur de sécurité, érigé par les Forces armées royales et non sur le territoire mauritanien.',
#    'url': 'https://www.yabiladi.com/articles/details/120677/affaires-camionneurs-algeriens-elements-minurso.html',
#    'source': 'yabiladi.com',
#    'image': 'https://static.yabiladi.com/files/articles/8db9d5f4bb36b61f7aaf0795eef7ef0120211104135634150.jpg',
#    'category': 'general',
#    'language': 'ar',
#    'country': 'ma',
#    'published_at': '2021-11-04T13:00:00+00:00'},
#   {'author': None,
#    'title': 'بسبب غياب أغويرو لـ&quot;فترة طويلة&quot;.. برشلونة يفكر في ضم مهاجم جديد وتفادي تكرار &quot;سيناريو بواتينغ وبرايثوايت&quot;',
#    'description': 'دفعت الأزمة القلبية التي عانى منها سيرجيو أغويرو، فريقه إف سي برشلونة، لبدء البحث عن مهاجم جديد، قصد التعاقد معه في الميركاتو الشتوي المقبل، وسد الفراغ الذي سيتركه غياب المهاجم الأرجنتيني.وكان أغويرو',
#    'url': 'http://www.elbotola.com/article/2021-11-03-17-12-691.html',
#    'source': 'Elbotola.com',
#    'image': None,
#    'category': 'general',
#    'language': 'ar',
#    'country': 'ma',
#    'published_at': '2021-11-04T09:05:30+00:00'},
#   {'author': None,
#    'title': 'ليكون &quot;عبرة للآخرين&quot;.. السجن 10 أسابيع لمشجع (52 سنة) شتم &quot;ثلاثي&quot; منتخب إنجلترا بعبارات عنصرية',
#    'description': 'أصدرت محكمة في إنجلترا، عقوبة "صارمة" في حق مشجع إنجليزي، استخدم عبارات عنصرية ضد الثلاثي جادون سانشو وماركوس راشفورد وبوكايو ساكا، بعد نهائي كأس أمم أوروبا "يورو 2020".وتم اعتقال مشجع يبلغ من العمر 5',
#    'url': 'http://www.elbotola.com/article/2021-11-04-14-09-708.html',
#    'source': 'Elbotola.com',
#    'image': None,
#    'category': 'general',
#    'language': 'ar',
#    'country': 'ma',
#    'published_at': '2021-11-04T14:15:36+00:00'},
#   {'author': None,
#    'title': 'صحبفة &#x27;سبورت&#x27;: &quot;تشافي يجتمع برئيس السد وبرشلونة قد يعلن عن التعاقد مع المدرب الإسباني غدا الجمعة&quot;',
#    'description': 'ستكون الساعات القليلة القادمة، حاسمة في مستقبل المدرب الإسباني تشافي هيرنانديز، الذي يرغب في الانتقال إلى إف سي برشلونة، بينما يرفض السد القطري التخلي عنه.وحسب صحيفة "سبورت" الكتلونية، فإن لقاء هاما س',
#    'url': 'http://www.elbotola.com/article/2021-11-04-10-05-685.html',
#    'source': 'Elbotola.com',
#    'image': None,
#    'category': 'general',
#    'language': 'ar',
#    'country': 'ma',
#    'published_at': '2021-11-04T13:20:36+00:00'},
#   {'author': None,
#    'title': 'La BAD mobilise 120 millions d’euros pour soutenir les entrepreneurs au Maroc',
#    'description': 'Le Conseil dadministration du Groupe de la Banque africaine de développement (BAD) a approuvé, mercredi à Abidjan, un prêt de 120 millions d’euros en faveur du Maroc pour mettre en œuvre le programme d’appui à l’inclusion financière, à l’entrepreneuriat et aux très petites et moyennes entreprises (TPME). L’appui de la Banque aidera les entreprises en difficulté à relancer leur activité et à préserver les emplois dans le but de réussir la sortie de crise liée à la pandémie de Covid-19, explique un communiqué.',
#    'url': 'https://www.yabiladi.com/articles/details/121405/mobilise-millions-d-euros-pour-soutenir.html',
#    'source': 'yabiladi.com',
#    'image': 'https://static.yabiladi.com/files/articles/e13273aa0de8f10374a5387afd3c183020211124174732150.jpg',
#    'category': 'general',
#    'language': 'ar',
#    'country': 'ma',
#    'published_at': '2021-11-24T16:48:00+00:00'},
#   {'author': None,
#    'title': 'Avion détourné à Majorque\xa0: Trois fugitifs marocains arrêtés, 6 autres toujours recherchés',
#    'description': 'La police nationale et la garde civile ont arrêté, ce mercredi matin, trois Marocains dans les vingtaines, qui faisaient l’objet d’un groupe de 9 autres compatriotes qui s’étaient évadés d’un avion d’Air Arabia Maroc à Palma de Majorque, le 5 novembre dernier. Les jeunes, âgés de 26, 33 et 35 ans, ont été arrêtés dans la commune majorquine de Sencelles en tant qu’auteurs présumés d’un délit de sédition et de violation de la loi sur l’immigration, écrit OK Diario.',
#    'url': 'https://www.yabiladi.com/articles/details/121393/avion-detourne-majorque-trois-fugitifs.html',
#    'source': 'yabiladi.com',
#    'image': 'https://static.yabiladi.com/files/articles/500945042cf171fac411077058b1938c20211124151904150.jpg',
#    'category': 'general',
#    'language': 'ar',
#    'country': 'ma',
#    'published_at': '2021-11-24T14:50:00+00:00'},
#   {'author': 'إعلام',
#    'title': 'الصحة العالمية تحذر من خطورة المضادات الحيوية - E3lam.Com',
#    'description': 'كشفت الدكتورة مها طلعت، المستشارة الإقليمية لمقاومة مضادات الميكروبات بمنظمة الصحة العالمية لشرق المتوسط، خطورة المضادات الحيوية ع',
#    'url': 'http://thinakhbarak.local/articles/43108480-%D8%A7%D9%84%D8%B5%D8%AD%D8%A9-%D8%A7%D9%84%D8%B9%D8%A7%D9%84%D9%85%D9%8A%D8%A9-%D8%AA%D8%AD%D8%B0%D8%B1-%D9%85%D9%86-%D8%AE%D8%B7%D9%88%D8%B1%D8%A9-%D8%A7%D9%84%D9%85%D8%B6%D8%A7%D8%AF%D8%A7%D8%AA',
#    'source': 'Akhbarak.net',
#    'image': 'https://akhbarak.net/photos/articles-photos/2021/11/25/43108480/43108480-large.jpg?1637798544',
#    'category': 'general',
#    'language': 'ar',
#    'country': 'eg',
#    'published_at': '2021-11-25T00:02:20+00:00'},
#   {'author': None,
#    'title': 'عرض «The Stand Up Sketch Show» بنسختها الأولى في الشرق الأوسط على «شاهد VIP»',
#    'description': 'أعلنت منصة "شاهد VIP"، عن استحواذها - حصريًا - على عرض النسخة المحلية الخاصة بمنطقة الشرق الأوسط وشمال إفريقيا من سلسلة الستاند أب كوميدي العالمية الشهيرة «The Stand UP Sketch Show». يأتي هذا الإعلان بعد الاتفاق على منح استوديوهات «بي بي سي – BBC Studio»، حقوق إنتاج نسخة الشرق الأوسط من البرنامج لصالح',
#    'url': 'https://www.dostor.org/3635721',
#    'source': 'Dostor',
#    'image': 'https://www.dostor.org/UploadCache/libfiles/347/5/200x112o/686.jpg',
#    'category': 'general',
#    'language': 'ar',
#    'country': 'eg',
#    'published_at': '2021-11-24T10:20:29+00:00'},
#   {'author': None,
#    'title': "Retour sur l'unique petit-déjeuner entre Hassan II et Fidel Castro à Rabat en avril 1963",
#    'description': 'En avril 1963 Fidel Castro effectuait son premier voyage officiel en Union soviétique. L’avion qui le transportait à Moscou a fait escale à Rabat, le temps de prendre le petit déjeuner avec Hassan II. Les deux hommes discutèrent pendant deux heures, racontait le monarque dans «Mémoires d’un roi». La discussion a montré les profondes divergences entre les deux hommes.',
#    'url': 'https://www.yabiladi.com/articles/details/48805/retour-l-unique-petit-dejeuner-entre-hassan.html',
#    'source': 'yabiladi.com',
#    'image': 'https://static.yabiladi.com/files/articles/892a7e09989f57b7eed56239e861e238150.jpg',
#    'category': 'general',
#    'language': 'ar',
#    'country': 'ma',
#    'published_at': '2021-11-25T07:00:00+00:00'},
#   {'author': None,
#    'title': 'طاليب بعد الفوز على الرجاء: &quot;أظهرنا للجميع أننا أضعنا نقطتين أمام الجيش الملكي وانتصارنا على &#x27;الخضر&#x27; سيعيد الثقة لمكونات النادي&quot;',
#    'description': 'أكد عبد الرحيم طاليب، مدرب أولمبيك آسفي، أن انتصار فريقه على الرجاء الرياضي بهدف نظيف، جاء ليعيد الثقة لكامل مكونات النادي، مشيرا إلى أنه سيعمل على بناء فريق ثان خلال فترة توقف المسابقة.وقال طاليب في',
#    'url': 'http://www.elbotola.com/article/2021-11-24-10-32-992.html',
#    'source': 'Elbotola.com',
#    'image': None,
#    'category': 'general',
#    'language': 'ar',
#    'country': 'ma',
#    'published_at': '2021-11-24T10:35:31+00:00'},
#   {'author': None,
#    'title': 'تخوف من &quot;الكاف&quot; بسبب الوتيرة البطيئة للأشغال.... هل ستجرى النسخة القادمة لـ&quot;الكان&quot; في موعدها أم أن مصيرها التأجيل أو تحويلها لبلد آخر؟!',
#    'description': 'يترقب المهتمون بالشأن الرياضي الأفريقي، مصير النسخة القادمة من كأس أمم أفريقيا، المزمع إقامتها، مطلع السنة القادمة في الكاميرون.وأثارت مراسلة من الاتحاد الأفريقي لكرة القدم "كاف"، وجهتها بلغة "شديدة ا',
#    'url': 'http://www.elbotola.com/article/2021-11-24-22-16-252.html',
#    'source': 'Elbotola.com',
#    'image': None,
#    'category': 'general',
#    'language': 'ar',
#    'country': 'ma',
#    'published_at': '2021-11-24T22:20:36+00:00'},
#   {'author': None,
#    'title': '-عصابة الاربعة-! -1- -ساويرس/دحلان/الامارات/اسرائيل-. عندما يكون الدولار، اهم من القيم الانسانية وكرامة المواطن، وامن الوطن! نجيب ساويرس، نموذجاً. -1- - سعيد علام',
#    'description': '#الحوار_المتمدن #سعيد_...',
#    'url': 'https://www.ssrcaw.org/ar/show.art.asp?aid=738828',
#    'source': 'Ahewar.org',
#    'image': 'https://ahewar.net/Upload/user/images/716d48b6-ce8c-401c-a992-a8b47ff4e8fc.jpg',
#    'category': 'general',
#    'language': 'ar',
#    'country': 'iq',
#    'published_at': '2021-11-24T21:55:35+00:00'},
#   {'author': None,
#    'title': 'مصر تتسلم 1.3 مليون جرعة من لقاح &quot;جونسون آند جونسون&quot; عبر &quot;كوفاكس&quot;',
#    'description': '',
#    'url': 'http://www.nablustv.net/?page=details&cat=15&newsID=413697',
#    'source': 'nablus TV',
#    'image': '',
#    'category': 'general',
#    'language': 'ar',
#    'country': 'ps',
#    'published_at': '2021-11-25T05:45:40+00:00'},
#   {'author': None,
#    'title': 'L’ambassade d’allemagne au Maroc dément la publication d’un rapport des renseignements',
#    'description': 'L’ambassade allemande à Rabat dément l’authenticité d’un rapport attribué aux services de renseignements en Allemagne (BND), consacré aux relations avec le Maroc. Le texte aurait\xa0rédigé par Isabel Werenfels, présentée par certains médias marocains comme la cheffe du bureau de renseignement pour l’Afrique du Nord et le Moyen-Orient au sein du BND. La semaine dernière, des extraits du prétendu rapport intitulé «Nous ne voulons pas d’une nouvelle Turquie en Méditerranée occidental», ont été relayé par certains sites marocains.\xa0',
#    'url': 'https://www.yabiladi.com/articles/details/121900/l-ambassade-d-allemagne-maroc-dement-publication.html',
#    'source': 'yabiladi.com',
#    'image': 'https://static.yabiladi.com/files/articles/48ac2e85b365e88d32aa98d0762576b020211207235134150.png',
#    'category': 'general',
#    'language': 'ar',
#    'country': 'ma',
#    'published_at': '2021-12-07T22:58:00+00:00'},
#   {'author': None,
#    'title': 'Ceuta : Cinq mineurs marocains portés disparus après avoir tenté de se rendre en Espagne',
#    'description': 'En Espagne et à Ceuta, les autorités locales et les ONG sont mobilisées depuis mardi 30 novembre, après la disparition de cinq mineurs marocains isolés arrivés dans la ville en mai, qui auraient entrepris la traversée de la ville autonome en direction de la péninsule. Selon l’agence espagnole EFE et le média local El Faro de Ceuta, Ahmed El Mehdi, Alae Akka, Tarik Rbati, Brahim Abughar et Yahya Laroussi se seraient rencontrés, la nuit du mardi 30 novembre, pour «monter à bord d’un bateau gris» et partir pour l’Espagne.',
#    'url': 'https://www.yabiladi.com/articles/details/121879/ceuta-cinq-mineurs-marocains-portes.html',
#    'source': 'yabiladi.com',
#    'image': 'https://static.yabiladi.com/files/articles/ed7288c2211a776093a110c84dc3ee8f20211207154320150.jpg',
#    'category': 'general',
#    'language': 'ar',
#    'country': 'ma',
#    'published_at': '2021-12-07T14:57:00+00:00'},
#   {'author': None,
#    'title': '-كأس العرب- التي سيفوز بها -العجم- - أحمد عصيد',
#    'description': '#الحوار_المتمدن #أحمد_عصيد يحتج الأمازيغ والكورد والأقباط والزنوج والأشوريون وغيرهم من القوميات المتواجدة على خريطة شمال إفريقيا والشرق الأوسط ، على تسمية "كأس العرب" التي أطلقها عرب الخليج على الدوري المنظم حاليا بقطر، أقول عرب الخليج لأن "الفيفا" لم تطلق على الكأس إسم "كأس العرب" بل أسمتها الكأس العربية Arab Cup أو بالفرنسية La coupe...',
#    'url': 'https://www.ssrcaw.org/ar/show.art.asp?aid=740098',
#    'source': 'Ahewar.org',
#    'image': 'https://ahewar.net/Upload/user/images/20fc485e-854a-467b-9a39-d893a10ffc96.jpg',
#    'category': 'general',
#    'language': 'ar',
#    'country': 'iq',
#    'published_at': '2021-12-07T16:41:08+00:00'},
#   {'author': None,
#    'title': 'L’Algérie boycotte la CAN de handball organisée à Guelmim et Laayoune',
#    'description': 'C’est désormais officiel. L’Algérie ne prendra pas part à la 25e édition de la Coupe d’Afrique des Nations Seniors Hommes de Handball, qui sera organisée du 13 au 23 janvier 2022 à Guelmim et Laayoune au Maroc. Hier, la Confédération Africaine de Handball a levé le voile sur la liste des pays concernés par le tirage au sort de la compétition. L’équipe algérienne, pourtant qualifiée, n’y figure pas.',
#    'url': 'https://www.yabiladi.com/articles/details/121919/l-algerie-boycotte-handball-organisee-guelmim.html',
#    'source': 'yabiladi.com',
#    'image': 'https://static.yabiladi.com/files/articles/06d72e2a7570cff53481268f40b48e5920211208182714150.jpeg',
#    'category': 'general',
#    'language': 'ar',
#    'country': 'ma',
#    'published_at': '2021-12-08T17:27:00+00:00'},
#   {'author': None,
#    'title': 'Maroc : Report sine die du championnat de cyclisme du Maroc',
#    'description': 'Le championnat du Maroc de courses sur route pour la saison 2021-2022, initialement prévu du 10 au 12 décembre à Benslimane, a été reporté à une date ultérieure non fixée, a annoncé mardi la Fédération royale marocaine de Cyclisme (FRMC) dans un communiqué. Ce report sexplique par la situation sanitaire et épidémiologique au Maroc et dans le monde en raison de la covid-19 et ses nouveaux variants.',
#    'url': 'https://www.yabiladi.com/articles/details/121907/maroc-report-sine-championnat-cyclisme.html',
#    'source': 'yabiladi.com',
#    'image': 'https://static.yabiladi.com/files/articles/d724a69734a6c99bd2909998cfd0fe9220211208092746150.jpg',
#    'category': 'general',
#    'language': 'ar',
#    'country': 'ma',
#    'published_at': '2021-12-08T08:29:00+00:00'},
#   {'author': None,
#    'title': 'France : Un projet d’attentat au couteau pendant les fêtes de Noël déjoué',
#    'description': 'Les services de la Direction générale de la sécurité intérieure (DGSI) ont interpellé le 29 novembre dernier deux hommes de 23 ans à Meaux en Seine-et-Marne et au Pecq dans les Yvelines qui avaient projeté de commettre un attentat terroriste au couteau pendant les fêtes de Noël, apprend-on du Parisien.',
#    'url': 'https://www.yabiladi.com/articles/details/121926/france-projet-d-attentat-couteau-pendant.html',
#    'source': 'yabiladi.com',
#    'image': 'https://static.yabiladi.com/files/articles/457e4a46e4a6c611aa5bf8c3db491e8320211208161613150.jpg',
#    'category': 'general',
#    'language': 'ar',
#    'country': 'ma',
#    'published_at': '2021-12-08T15:40:00+00:00'},
#   {'author': None,
#    'title': "Maroc : Le ministère de la Solidarité est déterminé à valoriser l'image de la femme dans les médias",
#    'description': 'La ministre de la Solidarité, de lintégration sociale et de la famille, Aawatif Hayar, a affirmé lundi à Rabat que son département est déterminé à renforcer la prise en charge des femmes et des filles victimes de violences et à valoriser limage de la gent féminine dans les médias.',
#    'url': 'https://www.yabiladi.com/articles/details/121858/maroc-ministere-solidarite-determine-valoriser.html',
#    'source': 'yabiladi.com',
#    'image': 'https://static.yabiladi.com/files/articles/91105834523d8022ae7f95fdf8aef9b020211207091645150.jpeg',
#    'category': 'general',
#    'language': 'ar',
#    'country': 'ma',
#    'published_at': '2021-12-07T08:18:00+00:00'},
#   {'author': None,
#    'title': 'الجزائر تبلغ المباراة رقم 36 دون هزيمة.. هل يكسر &quot;الأسود&quot; سلسلة &quot;الخضر&quot; ويحرمهم من معادلة رقم إيطاليا &quot;القياسي&quot;؟',
#    'description': 'واصلت الجزائر سلسلة "اللا هزيمة" التي تملكها، حين تعادلت اليوم الثلاثاء، أمام مصر بهدف نظيف، لحساب الجولة الثالثة من المجموعة الرابعة لكأس العرب التي تستضيفها قطر حتى الـ18 من شهر دجنبر الجاري.وبلغ عد',
#    'url': 'http://www.elbotola.com/article/2021-12-07-23-00-120.html',
#    'source': 'Elbotola.com',
#    'image': None,
#    'category': 'general',
#    'language': 'ar',
#    'country': 'ma',
#    'published_at': '2021-12-07T23:00:32+00:00'},
#   {'author': None,
#    'title': '&quot;الكاف&quot; ينفي تأجيل أو نقل &quot;الكان&quot; من الكاميرون ويؤكد إقامتها في موعدها ومكانها المُحدّديْن',
#    'description': 'فنَّد الاتحاد الأفريقي لكرة القدم ما راج بشأن إمكانية تغيير مكان نهائيات كأس أمم أفريقيا وسحبها من الكاميرون، مؤكداً في الوقت نفسه أن المسابقة القارية ستُقام في مكانها وموعدها المحددين، ما بين التاسع',
#    'url': 'http://www.elbotola.com/article/2021-12-08-12-22-400.html',
#    'source': 'Elbotola.com',
#    'image': None,
#    'category': 'general',
#    'language': 'ar',
#    'country': 'ma',
#    'published_at': '2021-12-08T12:25:29+00:00'},
#   {'author': None,
#    'title': 'USFP : Le verrou limitant les mandats de Lachagr a deux, a sauté',
#    'description': 'Driss Lachgar est pressenti pour\xa0conduire à nouveau l’USFP pour les cinq années à venir. Le verrou qui limitait ses ambitions à remplier pour un troisième mandat, vient de sauter. Le conseil national du Parti de la Rose a adopté, ce samedi, sa modification à une large majorité\xa0: 201 pour et seulement 9 voix contre.',
#    'url': 'https://www.yabiladi.com/articles/details/122310/usfp-verrou-limitant-mandats-lachagr.html',
#    'source': 'yabiladi.com',
#    'image': 'https://static.yabiladi.com/files/articles/9d6f59bcf92d462d7672e7bfc1be2f0420211218230405150.png',
#    'category': 'general',
#    'language': 'ar',
#    'country': 'ma',
#    'published_at': '2021-12-18T22:07:00+00:00'},
#   {'author': None,
#    'title': 'إنفانتينو مصمّم على تأجيل &quot;الكان&quot; وسط معارضة كبيرة لأعضاء الـ&quot;كاف&quot; المساندين للكاميرون',
#    'description': 'شدّد مصدر مطّلع على أن أعضاء المكتب التنفيذي للاتحاد الأفريقي لكرة القدم "كاف"، يرفضون فكرة تأجيل موعد إجراء نهائيات كأس أمم أفريقيا المزمع إقامتها في الفارة الممتدة من 9 يناير إلى 6 فبراير 2022.وأوضح',
#    'url': 'http://www.elbotola.com/article/2021-12-19-14-47-511.html',
#    'source': 'Elbotola.com',
#    'image': None,
#    'category': 'general',
#    'language': 'ar',
#    'country': 'ma',
#    'published_at': '2021-12-19T14:50:31+00:00'},
#   {'author': None,
#    'title': 'تفشي &quot;أوميكرون&quot; والتأثير على الكرة الأوروبية عاملان يؤيدان احتمالية &quot;التأجيل&quot; قبل اجتماع &quot;الكاف&quot; الحاسم',
#    'description': 'من المقرر أن يعقد أعضاء اللجنة التنفيذية للاتحاد الأفريقي لكرة القدم اجتماعا "حاسما" مساء يومه الأحد، بحضور السويسري جياني أنفانتينو، رئيس الاتحاد الدولي، للبث في مصير كأس أمم أفريقيا بين تأجيلها أو ت',
#    'url': 'http://www.elbotola.com/article/2021-12-19-14-52-401.html',
#    'source': 'Elbotola.com',
#    'image': None,
#    'category': 'general',
#    'language': 'ar',
#    'country': 'ma',
#    'published_at': '2021-12-19T14:55:33+00:00'},
#   {'author': None,
#    'title': 'الدفاع الجديدي لـ&quot;البطولة&quot;: &quot;بن شيخة لازال عالقا في فرنسا وننتظر تدخل وزارة الخارجية&quot;',
#    'description': 'شدد مصدر مسؤول داخل نادي الدفاع الحسني الجديدي، أن وضعية مدرب الفريق عبد الحق بن شيخة لازالت "غامضة"، بعد تمديد إغلاق المجال الجوي في وجه الرحلات المباشرة للمسافرين من وإلى المملكة المغربية.وأوضح المص',
#    'url': 'http://www.elbotola.com/article/2021-12-17-16-23-302.html',
#    'source': 'Elbotola.com',
#    'image': None,
#    'category': 'general',
#    'language': 'ar',
#    'country': 'ma',
#    'published_at': '2021-12-17T16:25:32+00:00'},
#   {'author': None,
#    'title': 'برشلونة ينجو من فخ إلتشي بـ&quot;روح شبابه&quot; ويستعيد &quot;نغمة الانتصارات&quot; في الدوري الإسباني',
#    'description': 'نجا برشلونة من فخ ضيفه إلتشي بعد تغلبه عليه بثلاثة أهداف مقابل اثنين، في المباراة التي جمعت الطرفين على أرضية ملعب "كامب نو" لحساب الجولة الـ18 من الدوري الإسباني.وشهدت المباراة مشاركة المغربي عبد الص',
#    'url': 'http://www.elbotola.com/article/2021-12-18-19-24-959.html',
#    'source': 'Elbotola.com',
#    'image': None,
#    'category': 'general',
#    'language': 'ar',
#    'country': 'ma',
#    'published_at': '2021-12-18T19:25:33+00:00'},
#   {'author': None,
#    'title': 'أوروبا تواصل الضغط.. &quot;ديلي ميل&quot;: &quot;الأندية الإنجليزية تؤيد فكرة تأجيل كأس أمم أفريقيا&quot;!',
#    'description': 'تواصل الدوريات الأوروبية، ممارسة "ضغط شرس"، على الاتحاد الأفريقي لكرة القدم، مع اقتراب انطلاق كأس أمم أفريقيا، المزمع إقامتها في الكاميرون، خلال الفترة المتراوحة ما بين 9 يناير و6 فبراير 2022.وأصدت ال',
#    'url': 'http://www.elbotola.com/article/2021-12-17-15-48-792.html',
#    'source': 'Elbotola.com',
#    'image': None,
#    'category': 'general',
#    'language': 'ar',
#    'country': 'ma',
#    'published_at': '2021-12-17T15:50:31+00:00'},
#   {'author': None,
#    'title': 'الجامعة لـ&quot;البطولة&quot;: &quot;عموتة سيعود إلى المغرب لمباشرة عمله ولا نكترث للأخبار الرائجة&quot;',
#    'description': 'أكد مصدر جامعي مسؤول، أن العقد الذي يربط الجامعة الملكية المغربية لكرة القدم، بمدرب المنتخب الرديف الحسين عموتة لازال ساري المفعول.وأوضح المسؤول الجامعي في اتصال هاتفي مع "البطولة"، أن عموتة بقي في قط',
#    'url': 'http://www.elbotola.com/article/2021-12-17-10-38-548.html',
#    'source': 'Elbotola.com',
#    'image': None,
#    'category': 'general',
#    'language': 'ar',
#    'country': 'ma',
#    'published_at': '2021-12-17T10:40:30+00:00'},
#   {'author': None,
#    'title': 'اقتراح باعتماد اللغة العربية &quot;لغة رسمية&quot; في الاتحاد الدولي لكرة القدم &quot;فيفا&quot;',
#    'description': 'يوافق اليوم الاحتفال باليوم العالمي للغة العربية، وختام منافسات كأس العرب "FIFA قطر 2021"، التي تقام للمرة الأولى تحت مظلة الاتحاد الدولي لكرة القدم (الفيفا).وتقديراً لأهمية اللغة العربية، التي يتحدث',
#    'url': 'http://www.elbotola.com/article/2021-12-18-16-32-376.html',
#    'source': 'Elbotola.com',
#    'image': None,
#    'category': 'general',
#    'language': 'ar',
#    'country': 'ma',
#    'published_at': '2021-12-18T16:35:31+00:00'},
#   {'author': 'Doha News Team',
#    'title': 'The Round Up | 07 December 2021',
#    'description': '(The post The Round Up | 07 December 2021 is from Doha News | Qatar.)',
#    'url': 'https://www.dohanews.co/the-round-up-07-december-2021/?utm_source=rss&utm_medium=rss&utm_campaign=the-round-up-07-december-2021',
#    'source': 'Doha News',
#    'image': None,
#    'category': 'general',
#    'language': 'ar',
#    'country': 'qa',
#    'published_at': '2021-12-19T07:02:50+00:00'},
#   {'author': 'Menatalla Ibrahim',
#    'title': 'Soon: Istimara to be renewed even if the vehicle has traffic violations',
#    'description': 'Previously, people had to pay for all their traffic violations before renewing their vehicle registration.\xa0 People living in Qatar will soon be able to renew their vehicle registration (Istimara) even if they have unpaid violations, authorities have announced. Speaking to Qatar TV, Colonel Jaber Mohamed Rashid Odaiba, Assistant Director of the Media and Traffic Awareness [&#8230;](The post Soon: Istimara to be renewed even if the vehicle has traffic violations is from Doha News | Qatar.)',
#    'url': 'https://www.dohanews.co/soon-istimara-to-be-renewed-even-if-the-vehicle-has-traffic-violations/?utm_source=rss&utm_medium=rss&utm_campaign=soon-istimara-to-be-renewed-even-if-the-vehicle-has-traffic-violations',
#    'source': 'Doha News',
#    'image': None,
#    'category': 'general',
#    'language': 'ar',
#    'country': 'qa',
#    'published_at': '2021-12-27T10:03:55+00:00'},
#   {'author': 'monjed jado',
#    'title': 'Displacing 16 people, Israeli occupation municipality demolishes Palestinian-owned building in occupied Jerusalem',
#    'description': 'Occupied Jerusalem/PNN/ The Israeli municipality of West Jerusalem today demolished a Palestinian-owned three-story building in Isawiyyeh neighborhood of occupied East Jerusalem displacing 16 people. She said that municipality staff protected by police, who cordoned off the area where the building is located, proceeded with the help of a bulldozer to demolish the building under the &#8230;التدوينة Displacing 16 people, Israeli occupation municipality demolishes Palestinian-owned building in occupied Jerusalem ظهرت أولاً على PNN.',
#    'url': 'http://english.pnn.ps/2021/12/27/displacing-16-people-israeli-occupation-municipality-demolishes-palestinian-owned-building-in-occupied-jerusalem/',
#    'source': 'english',
#    'image': None,
#    'category': 'general',
#    'language': 'ar',
#    'country': 'ps',
#    'published_at': '2021-12-27T19:12:44+00:00'},
#   {'author': 'Nathenael Gemechu',
#    'title': 'Will petrol station stores in Qatar start selling alcohol?',
#    'description': 'The Qatar Fuel Company (WOQOD) has come out denying false claims on social media. Following claims being made on several social media platforms, WOQOD, Qatar&#8217;s main fuel company and operator of most petrol stations in Doha, issued a statement dismissing as rumors, the claims that it had been granted a license for its outlets to [&#8230;](The post Will petrol station stores in Qatar start selling alcohol? is from Doha News | Qatar.)',
#    'url': 'https://www.dohanews.co/will-petrol-station-stores-in-qatar-start-selling-alcohol/?utm_source=rss&utm_medium=rss&utm_campaign=will-petrol-station-stores-in-qatar-start-selling-alcohol',
#    'source': 'Doha News',
#    'image': None,
#    'category': 'general',
#    'language': 'ar',
#    'country': 'qa',
#    'published_at': '2021-12-26T20:53:06+00:00'},
#   {'author': None,
#    'title': 'نابولي &#x27;يهدِّد&#x27; المنتخبات الأفريقية ومحامي النادي يؤكد: &quot;الفُرق استثمرت الكثير من الأموال للتعاقد مع اللاعبين&quot;',
#    'description': 'أصبحت الأندية الأوروبية، تضغط بكل الطرق الممكنة، للوقوف في وجه لاعبيها، ومنعهم من تمثيل منتخباتهم الوطنية، خلال كأس أمم أفريقيا الذي ستحتضنه الكاميرون مطلع السنة القادمة.وألمح محامي نابولي الإيطالي، إ',
#    'url': 'http://www.elbotola.com/article/2021-12-26-18-24-852.html',
#    'source': 'Elbotola.com',
#    'image': None,
#    'category': 'general',
#    'language': 'ar',
#    'country': 'ma',
#    'published_at': '2021-12-26T18:35:30+00:00'},
#   {'author': None,
#    'title': 'الجيش الملكي لـ&quot;العصبة الاحترافية&quot;: &quot;واجهنا السوالم بفريق مكون من الاحتياطيين والأمل رغم كوننا على موعد مع مباراة قارية!&quot;',
#    'description': 'ذكر نادي الجيش الملكي، خلال بلاغه الاستنكاري الذي أصدره اليوم الأحد، وسبق لـ"البطولة" الإشارة إليه في مواد سابقة، العصبة الوطنية لكرة القدم الاحترافية، بكونه خاض مباراة أمام الشباب الرياضي السالمي هذا',
#    'url': 'http://www.elbotola.com/article/2021-12-26-19-55-860.html',
#    'source': 'Elbotola.com',
#    'image': None,
#    'category': 'general',
#    'language': 'ar',
#    'country': 'ma',
#    'published_at': '2021-12-26T19:55:33+00:00'},
#   {'author': None,
#    'title': 'Maroc : Convention de partenariat pour le développement du sourcing local du Groupe Label’Vie',
#    'description': 'Une convention de partenariat pour le développement du sourcing local a été signée par le ministre de l’Industrie et du commerce, Ryad Mezzour, et le président du conseil d’administration du groupe Label’Vie (LBV), Zouhair Bennani, ce lundi à Rabat.',
#    'url': 'https://www.yabiladi.com/articles/details/122624/maroc-convention-partenariat-pour-developpement.html',
#    'source': 'yabiladi.com',
#    'image': 'https://static.yabiladi.com/files/articles/4d93a1870994c792dc5e2f7a4a3221ef20211227184443150.jpg',
#    'category': 'general',
#    'language': 'ar',
#    'country': 'ma',
#    'published_at': '2021-12-27T18:07:00+00:00'},
#   {'author': None,
#    'title': '&quot;صن&quot; البريطانية: &quot;تشيلسي يوافق على رحيل زياش وميلان أشد المهتمين بخدماته&quot;',
#    'description': 'عاد اقتراب نهاية رحلة الدولي المغربي حكيم زياش رفقة ناديه تشيلسي الإنجليزي، لتصدر وسائل الإعلام البريطانية، والتي أشارت يومه الإثنين، إلى رغبة الفريق اللندني في تسريح خدماته خلال الميركاتو الشتوي القا',
#    'url': 'http://www.elbotola.com/article/2021-12-27-18-13-295.html',
#    'source': 'Elbotola.com',
#    'image': None,
#    'category': 'general',
#    'language': 'ar',
#    'country': 'ma',
#    'published_at': '2021-12-27T18:15:33+00:00'},
#   {'author': None,
#    'title': 'بوجوده في &quot;مجموعة المغرب&quot;.. جزر القمر يسافر إلى السعودية للدخول في معسكر تدريبي قبل المشاركة في &quot;كان 2021&quot;',
#    'description': 'توجهت بعثة جزر القمر إلى المملكة العربية السعودية، اليوم الأحد، للدخول في معسكر تدريبي تأهبًا للمشاركة في كأس أمم أفريقيا المقبلة، والتي ستقام في الكاميرون خلال الفترة الممتدة من 9 يناير إلى 6 فبراير',
#    'url': 'http://www.elbotola.com/article/2021-12-26-13-28-9.html',
#    'source': 'Elbotola.com',
#    'image': None,
#    'category': 'general',
#    'language': 'ar',
#    'country': 'ma',
#    'published_at': '2021-12-26T13:55:32+00:00'},
#   {'author': None,
#    'title': 'الشاب &quot;جيان&quot; (18 سنة) يرفض اللعب مع غانا في &quot;الكان&quot; ويفضِّل البقاء مع فريق روما',
#    'description': 'كشف ميلوفان راييفاتس، مدرب المنتخب الغاني، الأسبوع الماضي، عن القائمة الأولية المكونة من 30 لاعبا، التي اختارها للمشاركة في كأس أمم أفريقيا "كان 2021"، وضمنها اسم لاعب روما الإيطالي، فيليكس أفينا-جيان',
#    'url': 'http://www.elbotola.com/article/2021-12-27-14-41-800.html',
#    'source': 'Elbotola.com',
#    'image': None,
#    'category': 'general',
#    'language': 'ar',
#    'country': 'ma',
#    'published_at': '2021-12-27T14:50:29+00:00'},
#   {'author': None,
#    'title': 'Histoire\xa0: Les aventures africaines du juif marocain Mordekhaï Aby Serour',
#    'description': 'C’est l’histoire d’un Marocain, de confession juive, ayant été à la fois rabbin, commerçant, trafiquant d’or, explorateur et géographe. A l’origine de l’arrivée des commerçants juifs à Tombouctou, Mordekhaï Aby Serour sera même guide pour Charles de Foucauld dans sa «reconnaissance du Maroc» en 1884.',
# ...
#    'url': 'http://english.pnn.ps/2021/10/20/ministry-of-tourism-announces-the-re-reception-of-foreign-tourists-to-stay-in-palestinian-hotels/',
#    'source': 'english',
#    'image': None,
#    'category': 'general',
#    'language': 'ar',
#    'country': 'ps',
#    'published_at': '2021-10-20T19:45:50+00:00'},
#   {'author': 'إعلام',
#    'title': 'نتفليكس تطرح برومو فيلم "RED NOTICE" - E3lam.Com',
#    'description': 'شاهد برومو فيلم RED NOTICE حيث طرحت منصة نتفليكس، الإعلان الدعائي لفيلم الأكشن RED NTICE المقرر طرحه 12 نوفمبر المقبل.',
#    'url': 'http://thinakhbarak.local/articles/42893739-%D9%86%D8%AA%D9%81%D9%84%D9%8A%D9%83%D8%B3-%D8%AA%D8%B7%D8%B1%D8%AD-%D8%A8%D8%B1%D9%88%D9%85%D9%88-%D9%81%D9%8A%D9%84%D9%85-quot-RED-NOTICE-quot--',
#    'source': 'Akhbarak.net',
#    'image': 'https://akhbarak.net/photos/articles-photos/2021/10/21/42893739/42893739-large.jpg?1634834486',
#    'category': 'general',
#    'language': 'ar',
#    'country': 'eg',
#    'published_at': '2021-10-21T16:41:20+00:00'},
#   {'author': None,
#    'title': 'سفير المملكة المغربية في تونس لـ&quot;البطولة&quot;: &quot;استقبال الجيش الملكي في مطار قرطاج مبادرة عادية وهدفها تشجيع الفريق قبل مباراته القادمة&quot;',
#    'description': 'أوضح حسن طارق، سفير المملكة المغربية في دولة تونس، أن استقبال بعثة الجيش الملكي بالورود في مطار قرطاج، يعتبر مبادرة عادية، تدخل في إطار تشجيع الفريق قبل مباراته القارية القادمة.وأكد حسن طارق في تصريح',
#    'url': 'http://www.elbotola.com/article/2021-10-22-14-15-168.html',
#    'source': 'Elbotola.com',
#    'image': None,
#    'category': 'general',
#    'language': 'ar',
#    'country': 'ma',
#    'published_at': '2021-10-22T14:15:31+00:00'},
#   {'author': None,
#    'title': "Antonio Costa : L'interconnexion électrique «fondamentale» Portugal-Maroc peut être «décisive à l'Europe»",
#    'description': 'Le Premier ministre portugais, Antonio Costa, a qualifié de «fondamentale» l’interconnexion électrique entre son pays et le Maroc lors d’un débat au Parlement portugais en préparation du prochain Conseil européen, rapporte Expresso.',
#    'url': 'https://www.yabiladi.com/articles/details/118968/antonio-costa-l-interconnexion-electrique-fondamentale.html',
#    'source': 'yabiladi.com',
#    'image': 'https://static.yabiladi.com/files/articles/1206964bf627869b409104e7d2562b5e20211022133143150.jpg',
#    'category': 'general',
#    'language': 'ar',
#    'country': 'ma',
#    'published_at': '2021-10-22T11:40:00+00:00'},
#   {'author': None,
#    'title': 'الـ&quot;فيفا&quot; يدعو لاجتماع &quot;عالمي&quot; لمناقشة خطط إقامة كأس العالم',
#    'description': 'أكد جياني إنفانتينو، رئيس الاتحاد الدولي لكرة القدم (فيفا) أنه سوف يتم عقد مؤتمر في 20 ديسمبر المقبل، بهدف طرح مقترح متفق عليه بشأن الرزنامة الدولية الجديدة لكرة القدم للرجال والسيدات.وذكرت وكالة الأن',
#    'url': 'http://www.elbotola.com/article/2021-10-20-20-10-478.html',
#    'source': 'Elbotola.com',
#    'image': None,
#    'category': 'general',
#    'language': 'ar',
#    'country': 'ma',
#    'published_at': '2021-10-21T08:15:29+00:00'},
#   {'author': 'اليوم السابع',
#    'title': 'جوينيث بالترو تعيد إطلالتها في التسعينات بعرض أزياء" Gucci Love Parade " - اليوم السابع',
#    'description': 'حضرت الممثلة جوينيث بالترو ومؤسسة "Goop "عرض أزياء" Gucci Love Parade "، الذى أقيم في كاليفورنيا يوم الثلاثاء من هذا الأسبوع وكانت مرتدية بذلة بأكمام طويلة',
#    'url': 'http://thinakhbarak.local/articles/42984346-%D8%AC%D9%88%D9%8A%D9%86%D9%8A%D8%AB-%D8%A8%D8%A7%D9%84%D8%AA%D8%B1%D9%88-%D8%AA%D8%B9%D9%8A%D8%AF-%D8%A5%D8%B7%D9%84%D8%A7%D9%84%D8%AA%D9%87%D8%A7-%D9%81%D9%8A-%D8%A7%D9%84%D8%AA%D8%B3%D8%B9%D9%8A%D9%86%D8%A7%D8%AA',
#    'source': 'Akhbarak.net',
#    'image': 'https://akhbarak.net/photos/articles-photos/2021/11/5/42984346/42984346-large.jpg?1636128408',
#    'category': 'general',
#    'language': 'ar',
#    'country': 'eg',
#    'published_at': '2021-11-05T16:06:43+00:00'},
#   {'author': 'إعلام',
#    'title': 'محمد حفظي: المسابقة الرسمية هو فيلم افتتاح الدورة 43 من مهرجان القاهرة - E3lam.Com',
#    'description': 'قال محمد حفظي رئيس مهرجان القاهرة السينمائي خلال المؤتمر الصحفي للدورة الـ43 اليوم الأحد إن فيلم افتتاح المهرجان سيكون المسابقة الرسمية و',
#    'url': 'http://thinakhbarak.local/articles/42994342-%D9%85%D8%AD%D9%85%D8%AF-%D8%AD%D9%81%D8%B8%D9%8A-%D8%A7%D9%84%D9%85%D8%B3%D8%A7%D8%A8%D9%82%D8%A9-%D8%A7%D9%84%D8%B1%D8%B3%D9%85%D9%8A%D8%A9-%D9%87%D9%88-%D9%81%D9%8A%D9%84%D9%85-%D8%A7%D9%81%D8%AA%D8%AA%D8%A7%D8%AD',
#    'source': 'Akhbarak.net',
#    'image': 'https://akhbarak.net/photos/articles-photos/2021/11/7/42994342/42994342-large.jpg?1636284776',
#    'category': 'general',
#    'language': 'ar',
#    'country': 'eg',
#    'published_at': '2021-11-07T11:32:50+00:00'},
#   {'author': 'Menatalla Ibrahim',
#    'title': 'Qatar boasts 1,400 eco-friendly ‘green buildings’',
#    'description': 'Qatar has taken major steps towards achieving sustainability goals in recent years.\xa0 Qatar has recorded more than 1400 buildings under the Global Sustainability Assessment System (GSAS), which highlights &#8220;green&#8221; infrastructures across the country, authorities have announced. “Qatar has the highest number of buildings (1,406) with Global Sustainability Assessment System (GSAS), green building standards,” authorities said [&#8230;](The post Qatar boasts 1,400 eco-friendly &#8216;green buildings&#8217; is from Doha News | Qatar.)',
#    'url': 'http://feedproxy.google.com/~r/DohaNews/~3/Bv4CtnWmXdw/',
#    'source': 'Doha News',
#    'image': None,
#    'category': 'general',
#    'language': 'ar',
#    'country': 'qa',
#    'published_at': '2021-11-07T10:21:50+00:00'},
#   {'author': None,
#    'title': 'Covid-19 au Maroc : 168 nouvelles infections et 5 décès ce samedi',
#    'description': 'Jusqu’à 17h ce jeudi, 168 cas du nouveau coronavirus ont été enregistrés au Maroc, sur 13 333 tests réalisés, portant à 947 307 le nombre de personnes infectées depuis le début de cette pandémie. De plus, 24 311 560 personnes ont reçu la première dose, 22 253 789 personnes ont reçu la deuxième et 1 518 576 personnes ont reçu la troisième dose du vaccin contre la Covid-19.',
#    'url': 'https://www.yabiladi.com/articles/details/120757/covid-19-maroc-nouvelles-infections-deces.html',
#    'source': 'yabiladi.com',
#    'image': 'https://static.yabiladi.com/files/articles/b38fa6cc371810bbc76a689fa2b3b8b820211106173823150.jpg',
#    'category': 'general',
#    'language': 'ar',
#    'country': 'ma',
#    'published_at': '2021-11-06T16:40:00+00:00'},
#   {'author': None,
#    'title': 'المحلل التحكيمي لـ&quot;أبو ظبي الرياضية&quot; عن لقطة أحداد وداري: &quot;الحكم تخوف من العودة للفار وإشهار البطاقة الحمراء لذلك قرر تركها دون مجازفة&quot;',
#    'description': 'يرى فريد علي، المحلل التحكيمي لقنوات أبو ظبي الرياضية، أن كريم صبري، حكم "الديربي البيضاوي"، لم يجازف بالتوقف عند لحظة إسقاط مدافع الوداد الرياضي أشرف داري لمهاجم الرجاء الرياضي حميد أحداد، مخافة إشها',
#    'url': 'http://www.elbotola.com/article/2021-11-06-19-45-921.html',
#    'source': 'Elbotola.com',
#    'image': None,
#    'category': 'general',
#    'language': 'ar',
#    'country': 'ma',
#    'published_at': '2021-11-06T19:50:33+00:00'},
#   {'author': None,
#    'title': 'هيدامو لـ&quot;البطولة&quot;: &quot;نستعد بشكل جيد وعازمون على تحقيق فوزنا الأول في دوري الأبطال أمام ريفر أنجلز&quot;',
#    'description': 'قال مدرب نادي الجيش الملكي النسوي، عبد الله هيدامو، إن فريقه يستهدف الفوز في مباراته أمام ريفر أنجلز غدا السبت، بهدف البصم على انطلاقة جيدة في بطولة دوري أبطال أفريقيا للسيدات.وأكد في تصريح لـ"البطولة',
#    'url': 'http://www.elbotola.com/article/2021-11-05-13-06-685.html',
#    'source': 'Elbotola.com',
#    'image': None,
#    'category': 'general',
#    'language': 'ar',
#    'country': 'ma',
#    'published_at': '2021-11-05T13:10:33+00:00'},
#   {'author': None,
#    'title': 'بعد نقل مباراته ضد أوغندا من &quot;أكادير&quot; إلى &quot;كوناكري&quot; لتجنب &quot;الضغوط الخارجية&quot;.. مدرب مالي يؤكد: &quot...',
#    'description': 'وجّه مدرب منتخب مالي، محمد ماغاسوبا، طلبًا إلى السلطات المحلية من أجل السماح لمنتخب "النسور" بإجراء مباراته الأخيرة في تصفيات أفريقيا المؤهلة إلى كأس العالم "قطر 2022" على أرضية الملعب الكبير بأكادير.',
#    'url': 'http://www.elbotola.com/article/2021-11-07-15-52-274.html',
#    'source': 'Elbotola.com',
#    'image': None,
#    'category': 'general',
#    'language': 'ar',
#    'country': 'ma',
#    'published_at': '2021-11-07T16:35:38+00:00'},
#   {'author': None,
#    'title': '&quot;الديربي البيضاوي&quot; في البطولة بين موسمي &quot;2000-2001 إلى 2009-2010&quot;.. 10 انتصارات للرجاء مقابل 4 للوداد و6 تعادلات',
#    'description': 'يحتضن يومه السبت، ملعب "محمد الخامس" في الدار البيضاء، "ديربي بيضاوي" جديد بين الوداد والرجاء الرياضيين، لحساب الجولة العاشرة من البطولة الاحترافية "إنوي".وتفوق الطرف الأخضر، في ديربيات الدوري، خلال ا',
#    'url': 'http://www.elbotola.com/article/2021-11-06-14-02-503.html',
#    'source': 'Elbotola.com',
#    'image': None,
#    'category': 'general',
#    'language': 'ar',
#    'country': 'ma',
#    'published_at': '2021-11-06T14:05:31+00:00'},
#   {'author': None,
#    'title': 'بيانات عمالية أممية صديقة: بيان الملتقى التأسيسي -للمنبر العمالي العربي المناهض للإمبريالية- - تيار الكفاح العمالى - مصر',
#    'description': '#الحوار_المتمدن #تيار_الكفاح_العمالى_-_...',
#    'url': 'https://www.ssrcaw.org/ar/show.art.asp?aid=736947',
#    'source': 'Ahewar.org',
#    'image': 'https://ahewar.net/Upload/user/images/2abeeff5-5b73-4044-a304-340d3347e403.jpg',
#    'category': 'general',
#    'language': 'ar',
#    'country': 'iq',
#    'published_at': '2021-11-07T01:30:32+00:00'},
#   {'author': 'ICT Business',
#    'title': 'الرئيس التنفيذي لشركة ASG\xa0 : حققنا نمواً بنسبة 40% ونفذنا مشروعات كبرى وعقدنا شراكات عالمية\xa0 - ICT Business Magazine - أي سي تي بيزنس',
#    'description': 'ماتشهده مصر من طفرة في كافة المجالات أمر يشهد به الجميع ، هذا ما أكد عليه المهندس باسم بهاء الرئيس ا',
#    'url': 'http://thinakhbarak.local/articles/43077383-%D8%A7%D9%84%D8%B1%D8%A6%D9%8A%D8%B3-%D8%A7%D9%84%D8%AA%D9%86%D9%81%D9%8A%D8%B0%D9%8A-%D9%84%D8%B4%D8%B1%D9%83%D8%A9-ASG-%D8%AD%D9%82%D9%82%D9%86%D8%A7-%D9%86%D9%85%D9%88%D8%A7%D9%8B',
#    'source': 'Akhbarak.net',
#    'image': 'https://akhbarak.net/photos/articles-photos/2021/11/20/43077383/43077383-large.jpg?1637416853',
#    'category': 'general',
#    'language': 'ar',
#    'country': 'eg',
#    'published_at': '2021-11-20T14:00:38+00:00'},
#   {'author': None,
#    'title': 'Premier League : Hakim Ziyech ne quittera pas Chelsea en janvier',
#    'description': 'Chelsea na aucune intention de laisser partir le Marocain Hakim Ziyech en janvier, a indiqué lentraîneur du club londonien Thomas Tuchel, avant la confrontation de son club avec Leicester City samedi pour le compte de la 12e journée du championnat dAngleterre de football. Lailier de 28 ans a fait lobjet de nombreuses rumeurs depuis la réouverture de la fenêtre des transferts, avec des noms qui reviennent souvent comme lAC Milan. Mais Tuchel est catégorique, le joueur fait toujours partie de ses plans et "il restera au moins jusquà la fin de la saison".',
#    'url': 'https://www.yabiladi.com/articles/details/121264/premier-league-hakim-ziyech-quittera.html',
#    'source': 'yabiladi.com',
#    'image': 'https://static.yabiladi.com/files/articles/524274faf6593382869e284c802216c320211121113520150.jpg',
#    'category': 'general',
#    'language': 'ar',
#    'country': 'ma',
#    'published_at': '2021-11-21T10:40:00+00:00'},
#   {'author': 'Hala Abdallah',
#    'title': 'Qatar welcomes ILO report on work-related incidents amid calls for transparency',
#    'description': 'The International Labour Organisation says its report gives the most accurate picture of construction workers’ conditions in Qatar.\xa0 A recent report by the International Labour Organisation (ILO) in Qatar shows gaps in data collection with regards to construction workers&#8217; injuries and deaths in the country. The ILO released on Friday an in-depth analysis of work-related [&#8230;](The post Qatar welcomes ILO report on work-related incidents amid calls for transparency is from Doha News | Qatar.)',
#    'url': 'https://www.dohanews.co/qatar-welcomes-ilo-report-on-work-related-incidents-amid-calls-for-transparency/?utm_source=rss&utm_medium=rss&utm_campaign=qatar-welcomes-ilo-report-on-work-related-incidents-amid-calls-for-transparency',
#    'source': 'Doha News',
#    'image': None,
#    'category': 'general',
#    'language': 'ar',
#    'country': 'qa',
#    'published_at': '2021-11-21T10:16:02+00:00'},
#   {'author': 'إعلام',
#    'title': 'شاهد.. كليب "ريحة الليمون" لـ هاني عادل - E3lam.Com',
#    'description': 'ريحة الليمون لهاني عادلطرح الفنان هاني عادل، كليب أغنيته الجديدة "ريحة الليمون" عبر قناته الخاصة على موقع الفيديوهات يوتيوب.',
#    'url': 'http://thinakhbarak.local/articles/43082659-%D8%B4%D8%A7%D9%87%D8%AF-%D9%83%D9%84%D9%8A%D8%A8-quot-%D8%B1%D9%8A%D8%AD%D8%A9-%D8%A7%D9%84%D9%84%D9%8A%D9%85%D9%88%D9%86-quot-%D9%84%D9%80-%D9%87%D8%A7%D9%86%D9%8A-%D8%B9%D8%A7%D8%AF%D9%84--',
#    'source': 'Akhbarak.net',
#    'image': 'https://akhbarak.net/photos/articles-photos/2021/11/21/43082659/43082659-large.jpg?1637492181',
#    'category': 'general',
#    'language': 'ar',
#    'country': 'eg',
#    'published_at': '2021-11-21T10:56:17+00:00'},
#   {'author': None,
#    'title': 'طارق ذياب: &quot;الزلزولي لاعب يملك الجرأة والسرعة ويمنح حلولا لبرشلونة&quot; وأبو تريكة يرد: &quot;تغييرات تشافي لم تكن فعالة باستثناء عبد الصمد&quot;',
#    'description': 'أثنى كل من المصري محمد أبو تريكة والتونسي طارق ذياب، محللا قنوات "بي إن سبورتس" القطرية، على الأداء الذي قدمه عبد الصمد الزلزولي، لاعب برشلونة، في "ديربي كتلونيا" ضد إسبانيول، والذي انتهى بفوز الـ"بلا',
#    'url': 'http://www.elbotola.com/article/2021-11-21-12-01-459.html',
#    'source': 'Elbotola.com',
#    'image': None,
#    'category': 'general',
#    'language': 'ar',
#    'country': 'ma',
#    'published_at': '2021-11-21T12:05:34+00:00'},
#   {'author': None,
#    'title': 'الشيبي &quot;يرد اعتباره&quot; أمام طاليب برسالة مشفرة واحتفالية خاصة على طريقة الإيطالي &quot;خابي&quot; بعد هدفه في شباك أ. آسفي',
#    'description': 'بعث محمد الشيبي، الظهير الأيمن لفريق الجيش الملكي، "رسائل مشفرة" لعبد الرحيم طاليب، قائد العارضة الفنية لأولمبيك آسفي، في المواجهة التي جمعت الفريقين لحساب الجولة الـ11 من البطولة الاحترافية "إنوي".وت',
#    'url': 'http://www.elbotola.com/article/2021-11-20-19-06-566.html',
#    'source': 'Elbotola.com',
#    'image': None,
#    'category': 'general',
#    'language': 'ar',
#    'country': 'ma',
#    'published_at': '2021-11-20T19:10:32+00:00'},
#   {'author': None,
#    'title': 'القسم الثاني.. &quot;الطاس&quot; يُسقط &quot;الواف&quot; وسطاد المغربي يتجاوز ش. بنجرير وجمعية سلا يتعادل مع &quot;الراك&quot;',
#    'description': 'تواصلت مباريات الجولة التاسعة من البطولة الاحترافية - القسم الثاني "إنوي"، اليوم السبت، بثلاثة لقاءات، جمعَ الأول الاتحاد البيضاوي بالوداد الفاسي، بينما دار الثاني بين جمعية سلا والراسينغ البيضاوي، ثم',
#    'url': 'http://www.elbotola.com/article/2021-11-20-16-51-738.html',
#    'source': 'Elbotola.com',
#    'image': None,
#    'category': 'general',
#    'language': 'ar',
#    'country': 'ma',
#    'published_at': '2021-11-20T16:55:34+00:00'},
#   {'author': None,
#    'title': 'Histoire du chiisme au Maroc : Quand les Fatimides ont fondé le premier pays chiite [2/4]',
#    'description': 'Lhistoire se poursuit sur\xa0Idriss Ier et son adhésion au chiisme. Les historiens s’accordent sur le fait que les Fatimides, venus au Maroc par l’Est, étaient de mouvance chiite.',
#    'url': 'https://www.yabiladi.com/articles/details/59523/histoire-chiisme-maroc-quand-fatimides.html',
#    'source': 'yabiladi.com',
#    'image': 'https://static.yabiladi.com/files/articles/81a2703913ea05fc8404eff6baf992c720171121162247150.jpg',
#    'category': 'general',
#    'language': 'ar',
#    'country': 'ma',
#    'published_at': '2021-11-21T07:00:00+00:00'}]}

# %% [markdown]
# ## Collect specific news with their index

# %% [markdown]
# Get the first news:

# %%
# Collect specific news with their index
responses5['data'][0]
# Out:
# {'author': 'Hala Abdallah',
#  'title': 'Taliban says its purge of officials unrelated to sanctioned ministers\xa0',
#  'description': 'The Taliban appointed ministers sanctioned by the US in its interim government. The Taliban has refused calls by the international community to remove ministers from its interim government under US and UN sanction threats, a senior official said according to a Sputnik report. In comments made to the Russian outlet, Taliban Spokesman Mohammad Naeem confirmed [&#8230;](The post Taliban says its purge of officials unrelated to sanctioned ministers\xa0 is from Doha News | Qatar.)',
#  'url': 'http://feedproxy.google.com/~r/DohaNews/~3/_3OlD8mmIAA/',
#  'source': 'Doha News',
#  'image': None,
#  'category': 'general',
#  'language': 'ar',
#  'country': 'qa',
#  'published_at': '2021-10-13T13:15:39+00:00'}

# %% [markdown]
# Get the 27th news:

# %%
# Collect specific news with their index
responses5['data'][26]
# Out:
# {'author': None,
#  'title': 'ليكون &quot;عبرة للآخرين&quot;.. السجن 10 أسابيع لمشجع (52 سنة) شتم &quot;ثلاثي&quot; منتخب إنجلترا بعبارات عنصرية',
#  'description': 'أصدرت محكمة في إنجلترا، عقوبة "صارمة" في حق مشجع إنجليزي، استخدم عبارات عنصرية ضد الثلاثي جادون سانشو وماركوس راشفورد وبوكايو ساكا، بعد نهائي كأس أمم أوروبا "يورو 2020".وتم اعتقال مشجع يبلغ من العمر 5',
#  'url': 'http://www.elbotola.com/article/2021-11-04-14-09-708.html',
#  'source': 'Elbotola.com',
#  'image': None,
#  'category': 'general',
#  'language': 'ar',
#  'country': 'ma',
#  'published_at': '2021-11-04T14:15:36+00:00'}

# %% [markdown]
# Get the 100th news:

# %%
# Collect specific news with their index
responses5['data'][99]
# Out:
# {'author': None,
#  'title': 'Histoire du chiisme au Maroc : Quand les Fatimides ont fondé le premier pays chiite [2/4]',
#  'description': 'Lhistoire se poursuit sur\xa0Idriss Ier et son adhésion au chiisme. Les historiens s’accordent sur le fait que les Fatimides, venus au Maroc par l’Est, étaient de mouvance chiite.',
#  'url': 'https://www.yabiladi.com/articles/details/59523/histoire-chiisme-maroc-quand-fatimides.html',
#  'source': 'yabiladi.com',
#  'image': 'https://static.yabiladi.com/files/articles/81a2703913ea05fc8404eff6baf992c720171121162247150.jpg',
#  'category': 'general',
#  'language': 'ar',
#  'country': 'ma',
#  'published_at': '2021-11-21T07:00:00+00:00'}

# %% [markdown]
# ## Get specific data individually using API response objects

# %% [markdown]
# #### Author

# %%
# Get specific data individually using their API response objects
print("Author: "+responses['data'][0]['author'])
# Out:
# Author: Hala Abdallah

# %% [markdown]
# #### Category

# %%
print("Category: "+responses['data'][0]['category'])
# Out:
# Category: general

# %% [markdown]
# #### Country

# %%
print("Country: "+responses['data'][0]['country'])
# Out:
# Country: qa

# %% [markdown]
# #### Description

# %%
print("Description: "+responses['data'][0]['description'])
# Out:
# Description: The Taliban appointed ministers sanctioned by the US in its interim government. The Taliban has refused calls by the international community to remove ministers from its interim government under US and UN sanction threats, a senior official said according to a Sputnik report. In comments made to the Russian outlet, Taliban Spokesman Mohammad Naeem confirmed [&#8230;](The post Taliban says its purge of officials unrelated to sanctioned ministers  is from Doha News | Qatar.)

# %% [markdown]
# #### Image

# %%
print("Image: "+responses['data'][0]['image'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-66e1b9c7e26b> in <module>
# ----> 1 print("Image: "+responses['data'][0]['image'])
#
# TypeError: can only concatenate str (not "NoneType") to str

# %% [markdown]
# #### Language

# %%
print("Language: "+responses['data'][0]['language'])
# Out:
# Language: ar

# %% [markdown]
# #### Published at

# %%
print("Published at: "+responses['data'][0]['published_at'])
# Out:
# Published at: 2021-10-13T13:15:39+00:00

# %% [markdown]
# #### Source

# %%
print("Source: "+responses['data'][0]['source'])
# Out:
# Source: Doha News

# %% [markdown]
# #### Title

# %%
print("Title: "+responses['data'][0]['title'])
# Out:
# Title: Taliban says its purge of officials unrelated to sanctioned ministers

# %% [markdown]
# #### URL

# %%
print("URL: "+responses['data'][0]['url'])
# Out:
# URL: http://feedproxy.google.com/~r/DohaNews/~3/_3OlD8mmIAA/

# %% [markdown]
# ## Scrape hundreds or more news and save them into a CSV file

# %% [markdown]
# #### Save scraped news to CSV file

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
# Python 3
import requests

# Collect 1000 of news or more with Python and mediastack
r = requests.get("http://api.mediastack.com/v1/news?access_key=YOUR_ACCESS_KEY&languages=en&categories=business,technology&limit=100")

responses = r.json()
responses

# Define the collected API responses
mediastackData = responses['data']

# Normalize or unnest the JSON response
from pandas.io.json import json_normalize
flatData = json_normalize(mediastackData)

# Create data frame, and save them to CSV
import pandas as pd
df = pd.DataFrame(flatData)
df.to_csv("mediastackSample.csv", encoding = 'utf-8', index = False)

# %% [markdown]
# #### Show the data frame

# %%
flatData
# Out:
#                author                                              title  \
# 0       GlobeNewswire  Center Coast Brookfield MLP & Energy Infrastru...
# 1             Reuters  Workers at Exxon Texas refinery reject contrac...
# 2                None  Cinemark enhances moviegoing experience with S...
# 3   Aria Alamalhodaei  Tesla will only use iron-based batteries for s...
# 4           Indu Bhan  Future Retail party to dispute with Amazon: Ar...
# ..                ...                                                ...
# 95       Alex Millson  Hundreds Sick as Onion-Linked Salmonella Outbr...
# 96               None           Dow EPS beats by $0.19, beats on revenue
# 97               None  First Trust Mortgage Income Fund declares $0.0...
# 98               None  KnowBe4 acquires SecurityAdvisor in stock and ...
# 99       Mike Butcher  Watch Edward Snowden launch Global Encryption ...
#
#                                           description  \
# 0   NEW YORK, Oct. 20, 2021 (GLOBE NEWSWIRE) &#821...
# 1   BEAUMONT &#8212; The two sides in the Exxon Mo...
# 2   Cinemark enhances moviegoing experience with S...
# 3   Tesla said Wednesday it will use iron-based ba...
# 4   This stance of the arbitration panel further b...
# ..                                                ...
# 95  Hundreds Sick as Onion-Linked Salmonella Outbr...
# 96           Dow EPS beats by $0.19, beats on revenue
# 97  First Trust Mortgage Income Fund declares $0.0...
# 98  KnowBe4 acquires SecurityAdvisor in stock and ...
# 99  Marginalized communities, survivors of abuse, ...
#
#                                                   url  \
# 0   https://financialpost.com/globe-newswire/cente...
# 1   https://financialpost.com/pmn/business-pmn/wor...
# 2   https://seekingalpha.com/news/3755883-cinemark...
# 3   https://techcrunch.com/2021/10/20/tesla-earnin...
# 4   https://www.financialexpress.com/industry/futu...
# ..                                                ...
# 95  https://www.bloombergquint.com/business/hundre...
# 96  https://seekingalpha.com/news/3755939-dow-eps-...
# 97  https://seekingalpha.com/news/3755934-first-tr...
# 98  https://seekingalpha.com/news/3755941-knowbe4-...
# 99  https://techcrunch.com/2021/10/21/watch-edward...
#
#                                    source  \
# 0   Financial Post | Canada Business News
# 1   Financial Post | Canada Business News
# 2                           Seeking Alpha
# 3                              TechCrunch
# 4                   The Financial Express
# ..                                    ...
# 95   Bloomberg | Latest And Live Business
# 96                          Seeking Alpha
# 97                          Seeking Alpha
# 98                          Seeking Alpha
# 99                             TechCrunch
#
#                                                 image    category language  \
# 0                                                None    business       en
# 1                                                None    business       en
# 2                                                None    business       en
# 3                                                None  technology       en
# 4   https://images.financialexpress.com/2021/10/am...    business       en
# ..                                                ...         ...      ...
# 95                                               None    business       en
# 96                                               None    business       en
# 97                                               None    business       en
# 98                                               None    business       en
# 99                                               None  technology       en
#
#    country               published_at
# 0       us  2021-10-20T22:03:56+00:00
# 1       us  2021-10-20T22:11:57+00:00
# 2       us  2021-10-20T22:23:56+00:00
# 3       us  2021-10-20T22:55:23+00:00
# 4       us  2021-10-20T23:01:00+00:00
# ..     ...                        ...
# 95      us  2021-10-21T09:56:01+00:00
# 96      us  2021-10-21T10:06:23+00:00
# 97      us  2021-10-21T10:06:04+00:00
# 98      us  2021-10-21T10:11:53+00:00
# 99      us  2021-10-21T10:18:50+00:00
#
# [100 rows x 10 columns]
